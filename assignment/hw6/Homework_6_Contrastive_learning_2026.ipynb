# %% [markdown]
# # HW 6 Contrastive learning
#
# This assignment aims to have you learn how to modify loss functions and simultaneously process multiple feature vectors in both face verification and face recognition tasks by using the CelebA dataset as an example.
#
# CelebFaces Attributes Dataset (CelebA) is a large-scale face attributes dataset with more than 200K celebrity images, each with 40 attribute annotations, covering a wide range of pose variations and background clutter. The dataset is pruned so that the training time is appropriate for the assignment.
#
# This homework is divided into three parts:
#
# 1. Face verification with contrastive loss
# 2. Face verification with triplet loss
# 3. Face verification with InfoNCE loss
# 4. Face verification evaluation

# %% [markdown]
# # Import main libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import os.path as osp
from collections import defaultdict
from PIL import Image
import math
from tqdm.notebook import tqdm
import random

import torch
from torch import nn
import torch.nn.functional as F
from torch import optim
import torchvision
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

# %%
# !pwd
# Out:
# /home/chatrin/Documents/Chat/CU/Year-3/2110573-Pattern-Recognition/assignment/hw6

# %% [markdown]
# #Download and unzip the dataset

# %%
# !pip install gdown
# Out:
# Collecting gdown
#   Downloading gdown-5.2.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: beautifulsoup4 in /home/chatrin/Documents/Chat/CU/Year-3/2110573-Pattern-Recognition/.venv/lib/python3.11/site-packages (from gdown) (4.14.3)
# Requirement already satisfied: filelock in /home/chatrin/Documents/Chat/CU/Year-3/2110573-Pattern-Recognition/.venv/lib/python3.11/site-packages (from gdown) (3.25.0)
# Requirement already satisfied: requests[socks] in /home/chatrin/Documents/Chat/CU/Year-3/2110573-Pattern-Recognition/.venv/lib/python3.11/site-packages (from gdown) (2.32.5)
# Requirement already satisfied: tqdm in /home/chatrin/Documents/Chat/CU/Year-3/2110573-Pattern-Recognition/.venv/lib/python3.11/site-packages (from gdown) (4.67.3)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/chatrin/Documents/Chat/CU/Year-3/2110573-Pattern-Recognition/.venv/lib/python3.11/site-packages (from beautifulsoup4->gdown) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/chatrin/Documents/Chat/CU/Year-3/2110573-Pattern-Recognition/.venv/lib/python3.11/site-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/chatrin/Documents/Chat/CU/Year-3/2110573-Pattern-Recognition/.venv/lib/python3.11/site-packages (from requests[socks]->gdown) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/chatrin/Documents/Chat/CU/Year-3/2110573-Pattern-Recognition/.venv/lib/python3.11/site-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/chatrin/Documents/Chat/CU/Year-3/2110573-Pattern-Recognition/.venv/lib/python3.11/site-packages (from requests[socks]->gdown) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/chatrin/Documents/Chat/CU/Year-3/2110573-Pattern-Recognition/.venv/lib/python3.11/site-packages (from requests[socks]->gdown) (2026.2.25)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown)
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Downloading gdown-5.2.1-py3-none-any.whl (18 kB)
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Installing collected packages: PySocks, gdown
# Successfully installed PySocks-1.7.1 gdown-5.2.1
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !gdown --id 1_2oATmA0Jw61qs7I7kAG9Q2LHNZSQX7A
# Out:
# /home/chatrin/Documents/Chat/CU/Year-3/2110573-Pattern-Recognition/.venv/lib/python3.11/site-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1_2oATmA0Jw61qs7I7kAG9Q2LHNZSQX7A
# To: /home/chatrin/Documents/Chat/CU/Year-3/2110573-Pattern-Recognition/assignment/hw6/large_prepared_data.zip
# 100%|██████████████████████████████████████| 23.4M/23.4M [00:00<00:00, 44.9MB/s]

# %%
# !unzip content/large_prepared_data.zip
# Out:
# Archive:  content/large_prepared_data.zip
#    creating: large_prepared_data/
#    creating: large_prepared_data/test/
#    creating: large_prepared_data/train/
#    creating: large_prepared_data/val/
#   inflating: large_prepared_data/test/169872.jpg
#   inflating: __MACOSX/large_prepared_data/test/._169872.jpg
#   inflating: large_prepared_data/test/200868.jpg
#   inflating: __MACOSX/large_prepared_data/test/._200868.jpg
#   inflating: large_prepared_data/test/003315.jpg
#   inflating: __MACOSX/large_prepared_data/test/._003315.jpg
#   inflating: large_prepared_data/test/179485.jpg
#   inflating: __MACOSX/large_prepared_data/test/._179485.jpg
#   inflating: large_prepared_data/test/144506.jpg
#   inflating: __MACOSX/large_prepared_data/test/._144506.jpg
#   inflating: large_prepared_data/test/088865.jpg
#   inflating: __MACOSX/large_prepared_data/test/._088865.jpg
#   inflating: large_prepared_data/test/171344.jpg
#   inflating: __MACOSX/large_prepared_data/test/._171344.jpg
#   inflating: large_prepared_data/test/028219.jpg
#   inflating: __MACOSX/large_prepared_data/test/._028219.jpg
#   inflating: large_prepared_data/test/172498.jpg
#   inflating: __MACOSX/large_prepared_data/test/._172498.jpg
#   inflating: large_prepared_data/test/143686.jpg
#   inflating: __MACOSX/large_prepared_data/test/._143686.jpg
#   inflating: large_prepared_data/test/113933.jpg
#   inflating: __MACOSX/large_prepared_data/test/._113933.jpg
#   inflating: large_prepared_data/test/193840.jpg
#   inflating: __MACOSX/large_prepared_data/test/._193840.jpg
#   inflating: large_prepared_data/test/194322.jpg
#   inflating: __MACOSX/large_prepared_data/test/._194322.jpg
#   inflating: large_prepared_data/test/105413.jpg
#   inflating: __MACOSX/large_prepared_data/test/._105413.jpg
#   inflating: large_prepared_data/test/200302.jpg
#   inflating: __MACOSX/large_prepared_data/test/._200302.jpg
#   inflating: large_prepared_data/test/096441.jpg
#   inflating: __MACOSX/large_prepared_data/test/._096441.jpg
#   inflating: large_prepared_data/test/090232.jpg
#   inflating: __MACOSX/large_prepared_data/test/._090232.jpg
#   inflating: large_prepared_data/test/181467.jpg
#   inflating: __MACOSX/large_prepared_data/test/._181467.jpg
#   inflating: large_prepared_data/test/119372.jpg
#   inflating: __MACOSX/large_prepared_data/test/._119372.jpg
#   inflating: large_prepared_data/test/160128.jpg
#   inflating: __MACOSX/large_prepared_data/test/._160128.jpg
#   inflating: large_prepared_data/test/200894.jpg
#   inflating: __MACOSX/large_prepared_data/test/._200894.jpg
#   inflating: large_prepared_data/test/117613.jpg
#   inflating: __MACOSX/large_prepared_data/test/._117613.jpg
#   inflating: large_prepared_data/test/115986.jpg
#   inflating: __MACOSX/large_prepared_data/test/._115986.jpg
#   inflating: large_prepared_data/test/201787.jpg
#   inflating: __MACOSX/large_prepared_data/test/._201787.jpg
#   inflating: large_prepared_data/test/166983.jpg
#   inflating: __MACOSX/large_prepared_data/test/._166983.jpg
#   inflating: large_prepared_data/test/115170.jpg
#   inflating: __MACOSX/large_prepared_data/test/._115170.jpg
#   inflating: large_prepared_data/test/085205.jpg
#   inflating: __MACOSX/large_prepared_data/test/._085205.jpg
#   inflating: large_prepared_data/test/184641.jpg
#   inflating: __MACOSX/large_prepared_data/test/._184641.jpg
#   inflating: large_prepared_data/test/196245.jpg
#   inflating: __MACOSX/large_prepared_data/test/._196245.jpg
#   inflating: large_prepared_data/test/134828.jpg
#   inflating: __MACOSX/large_prepared_data/test/._134828.jpg
#   inflating: large_prepared_data/test/133174.jpg
#   inflating: __MACOSX/large_prepared_data/test/._133174.jpg
#   inflating: large_prepared_data/test/127673.jpg
#   inflating: __MACOSX/large_prepared_data/test/._127673.jpg
#   inflating: large_prepared_data/test/168602.jpg
#   inflating: __MACOSX/large_prepared_data/test/._168602.jpg
#   inflating: large_prepared_data/test/197826.jpg
#   inflating: __MACOSX/large_prepared_data/test/._197826.jpg
#   inflating: large_prepared_data/test/026753.jpg
#   inflating: __MACOSX/large_prepared_data/test/._026753.jpg
#   inflating: large_prepared_data/test/102551.jpg
#   inflating: __MACOSX/large_prepared_data/test/._102551.jpg
#   inflating: large_prepared_data/test/190999.jpg
#   inflating: __MACOSX/large_prepared_data/test/._190999.jpg
#   inflating: large_prepared_data/test/189576.jpg
#   inflating: __MACOSX/large_prepared_data/test/._189576.jpg
#   inflating: large_prepared_data/test/180778.jpg
#   inflating: __MACOSX/large_prepared_data/test/._180778.jpg
#   inflating: large_prepared_data/test/113855.jpg
#   inflating: __MACOSX/large_prepared_data/test/._113855.jpg
#   inflating: large_prepared_data/test/166979.jpg
#   inflating: __MACOSX/large_prepared_data/test/._166979.jpg
#   inflating: large_prepared_data/test/018294.jpg
#   inflating: __MACOSX/large_prepared_data/test/._018294.jpg
#   inflating: large_prepared_data/test/127070.jpg
#   inflating: __MACOSX/large_prepared_data/test/._127070.jpg
#   inflating: large_prepared_data/test/141281.jpg
#   inflating: __MACOSX/large_prepared_data/test/._141281.jpg
#   inflating: large_prepared_data/test/174945.jpg
#   inflating: __MACOSX/large_prepared_data/test/._174945.jpg
#   inflating: large_prepared_data/test/169041.jpg
#   inflating: __MACOSX/large_prepared_data/test/._169041.jpg
#   inflating: large_prepared_data/test/187827.jpg
#   inflating: __MACOSX/large_prepared_data/test/._187827.jpg
#   inflating: large_prepared_data/test/009978.jpg
#   inflating: __MACOSX/large_prepared_data/test/._009978.jpg
#   inflating: large_prepared_data/test/170288.jpg
#   inflating: __MACOSX/large_prepared_data/test/._170288.jpg
#   inflating: large_prepared_data/test/181265.jpg
#   inflating: __MACOSX/large_prepared_data/test/._181265.jpg
#   inflating: large_prepared_data/test/157179.jpg
#   inflating: __MACOSX/large_prepared_data/test/._157179.jpg
#   inflating: large_prepared_data/test/161144.jpg
#   inflating: __MACOSX/large_prepared_data/test/._161144.jpg
#   inflating: large_prepared_data/test/010971.jpg
#   inflating: __MACOSX/large_prepared_data/test/._010971.jpg
#   inflating: large_prepared_data/test/128578.jpg
#   inflating: __MACOSX/large_prepared_data/test/._128578.jpg
#   inflating: large_prepared_data/test/130323.jpg
#   inflating: __MACOSX/large_prepared_data/test/._130323.jpg
#   inflating: large_prepared_data/test/002434.jpg
#   inflating: __MACOSX/large_prepared_data/test/._002434.jpg
#   inflating: large_prepared_data/test/194250.jpg
#   inflating: __MACOSX/large_prepared_data/test/._194250.jpg
#   inflating: large_prepared_data/test/192386.jpg
#   inflating: __MACOSX/large_prepared_data/test/._192386.jpg
#   inflating: large_prepared_data/test/101288.jpg
#   inflating: __MACOSX/large_prepared_data/test/._101288.jpg
#   inflating: large_prepared_data/test/160851.jpg
#   inflating: __MACOSX/large_prepared_data/test/._160851.jpg
#   inflating: large_prepared_data/test/008521.jpg
#   inflating: __MACOSX/large_prepared_data/test/._008521.jpg
#   inflating: large_prepared_data/test/189983.jpg
#   inflating: __MACOSX/large_prepared_data/test/._189983.jpg
#   inflating: large_prepared_data/test/170842.jpg
#   inflating: __MACOSX/large_prepared_data/test/._170842.jpg
#   inflating: large_prepared_data/test/083100.jpg
#   inflating: __MACOSX/large_prepared_data/test/._083100.jpg
#   inflating: large_prepared_data/test/126755.jpg
#   inflating: __MACOSX/large_prepared_data/test/._126755.jpg
#   inflating: large_prepared_data/test/109953.jpg
#   inflating: __MACOSX/large_prepared_data/test/._109953.jpg
#   inflating: large_prepared_data/test/167708.jpg
#   inflating: __MACOSX/large_prepared_data/test/._167708.jpg
#   inflating: large_prepared_data/test/187617.jpg
#   inflating: __MACOSX/large_prepared_data/test/._187617.jpg
#   inflating: large_prepared_data/test/028792.jpg
#   inflating: __MACOSX/large_prepared_data/test/._028792.jpg
#   inflating: large_prepared_data/test/149807.jpg
#   inflating: __MACOSX/large_prepared_data/test/._149807.jpg
#   inflating: large_prepared_data/test/106902.jpg
#   inflating: __MACOSX/large_prepared_data/test/._106902.jpg
#   inflating: large_prepared_data/test/139516.jpg
#   inflating: __MACOSX/large_prepared_data/test/._139516.jpg
#   inflating: large_prepared_data/test/018781.jpg
#   inflating: __MACOSX/large_prepared_data/test/._018781.jpg
#   inflating: large_prepared_data/test/129560.jpg
#   inflating: __MACOSX/large_prepared_data/test/._129560.jpg
#   inflating: large_prepared_data/test/193567.jpg
#   inflating: __MACOSX/large_prepared_data/test/._193567.jpg
#   inflating: large_prepared_data/test/118226.jpg
#   inflating: __MACOSX/large_prepared_data/test/._118226.jpg
#   inflating: large_prepared_data/test/027983.jpg
#   inflating: __MACOSX/large_prepared_data/test/._027983.jpg
#   inflating: large_prepared_data/test/188219.jpg
#   inflating: __MACOSX/large_prepared_data/test/._188219.jpg
#   inflating: large_prepared_data/test/134486.jpg
#   inflating: __MACOSX/large_prepared_data/test/._134486.jpg
#   inflating: large_prepared_data/test/013992.jpg
#   inflating: __MACOSX/large_prepared_data/test/._013992.jpg
#   inflating: large_prepared_data/test/173082.jpg
#   inflating: __MACOSX/large_prepared_data/test/._173082.jpg
#   inflating: large_prepared_data/test/055253.jpg
#   inflating: __MACOSX/large_prepared_data/test/._055253.jpg
#   inflating: large_prepared_data/test/142840.jpg
#   inflating: __MACOSX/large_prepared_data/test/._142840.jpg
#   inflating: large_prepared_data/test/093214.jpg
#   inflating: __MACOSX/large_prepared_data/test/._093214.jpg
#   inflating: large_prepared_data/test/013825.jpg
#   inflating: __MACOSX/large_prepared_data/test/._013825.jpg
#   inflating: large_prepared_data/test/184568.jpg
#   inflating: __MACOSX/large_prepared_data/test/._184568.jpg
#   inflating: large_prepared_data/test/050088.jpg
#   inflating: __MACOSX/large_prepared_data/test/._050088.jpg
#   inflating: large_prepared_data/test/185689.jpg
#   inflating: __MACOSX/large_prepared_data/test/._185689.jpg
#   inflating: large_prepared_data/test/192487.jpg
#   inflating: __MACOSX/large_prepared_data/test/._192487.jpg
#   inflating: large_prepared_data/test/195667.jpg
#   inflating: __MACOSX/large_prepared_data/test/._195667.jpg
#   inflating: large_prepared_data/test/114345.jpg
#   inflating: __MACOSX/large_prepared_data/test/._114345.jpg
#   inflating: large_prepared_data/test/180256.jpg
#   inflating: __MACOSX/large_prepared_data/test/._180256.jpg
#   inflating: large_prepared_data/test/021473.jpg
#   inflating: __MACOSX/large_prepared_data/test/._021473.jpg
#   inflating: large_prepared_data/test/072765.jpg
#   inflating: __MACOSX/large_prepared_data/test/._072765.jpg
#   inflating: large_prepared_data/test/172605.jpg
#   inflating: __MACOSX/large_prepared_data/test/._172605.jpg
#   inflating: large_prepared_data/test/101364.jpg
#   inflating: __MACOSX/large_prepared_data/test/._101364.jpg
#   inflating: large_prepared_data/test/025563.jpg
#   inflating: __MACOSX/large_prepared_data/test/._025563.jpg
#   inflating: large_prepared_data/test/055912.jpg
#   inflating: __MACOSX/large_prepared_data/test/._055912.jpg
#   inflating: large_prepared_data/test/014783.jpg
#   inflating: __MACOSX/large_prepared_data/test/._014783.jpg
#   inflating: large_prepared_data/test/007066.jpg
#   inflating: __MACOSX/large_prepared_data/test/._007066.jpg
#   inflating: large_prepared_data/test/062403.jpg
#   inflating: __MACOSX/large_prepared_data/test/._062403.jpg
#   inflating: large_prepared_data/test/170946.jpg
#   inflating: __MACOSX/large_prepared_data/test/._170946.jpg
#   inflating: large_prepared_data/test/063325.jpg
#   inflating: __MACOSX/large_prepared_data/test/._063325.jpg
#   inflating: large_prepared_data/test/196151.jpg
#   inflating: __MACOSX/large_prepared_data/test/._196151.jpg
#   inflating: large_prepared_data/test/035167.jpg
#   inflating: __MACOSX/large_prepared_data/test/._035167.jpg
#   inflating: large_prepared_data/test/167147.jpg
#   inflating: __MACOSX/large_prepared_data/test/._167147.jpg
#   inflating: large_prepared_data/test/159254.jpg
#   inflating: __MACOSX/large_prepared_data/test/._159254.jpg
#   inflating: large_prepared_data/test/056173.jpg
#   inflating: __MACOSX/large_prepared_data/test/._056173.jpg
#   inflating: large_prepared_data/test/022143.jpg
#   inflating: __MACOSX/large_prepared_data/test/._022143.jpg
#   inflating: large_prepared_data/test/142847.jpg
#   inflating: __MACOSX/large_prepared_data/test/._142847.jpg
#   inflating: large_prepared_data/test/196237.jpg
#   inflating: __MACOSX/large_prepared_data/test/._196237.jpg
#   inflating: large_prepared_data/test/198583.jpg
#   inflating: __MACOSX/large_prepared_data/test/._198583.jpg
#   inflating: large_prepared_data/test/135946.jpg
#   inflating: __MACOSX/large_prepared_data/test/._135946.jpg
#   inflating: large_prepared_data/test/180657.jpg
#   inflating: __MACOSX/large_prepared_data/test/._180657.jpg
#   inflating: large_prepared_data/test/113003.jpg
#   inflating: __MACOSX/large_prepared_data/test/._113003.jpg
#   inflating: large_prepared_data/test/087676.jpg
#   inflating: __MACOSX/large_prepared_data/test/._087676.jpg
#   inflating: large_prepared_data/test/093824.jpg
#   inflating: __MACOSX/large_prepared_data/test/._093824.jpg
#   inflating: large_prepared_data/test/008392.jpg
#   inflating: __MACOSX/large_prepared_data/test/._008392.jpg
#   inflating: large_prepared_data/test/073053.jpg
#   inflating: __MACOSX/large_prepared_data/test/._073053.jpg
#   inflating: large_prepared_data/test/060991.jpg
#   inflating: __MACOSX/large_prepared_data/test/._060991.jpg
#   inflating: large_prepared_data/test/192252.jpg
#   inflating: __MACOSX/large_prepared_data/test/._192252.jpg
#   inflating: large_prepared_data/test/060239.jpg
#   inflating: __MACOSX/large_prepared_data/test/._060239.jpg
#   inflating: large_prepared_data/test/122624.jpg
#   inflating: __MACOSX/large_prepared_data/test/._122624.jpg
#   inflating: large_prepared_data/test/003832.jpg
#   inflating: __MACOSX/large_prepared_data/test/._003832.jpg
#   inflating: large_prepared_data/test/040248.jpg
#   inflating: __MACOSX/large_prepared_data/test/._040248.jpg
#   inflating: large_prepared_data/test/047269.jpg
#   inflating: __MACOSX/large_prepared_data/test/._047269.jpg
#   inflating: large_prepared_data/test/078925.jpg
#   inflating: __MACOSX/large_prepared_data/test/._078925.jpg
#   inflating: large_prepared_data/test/153236.jpg
#   inflating: __MACOSX/large_prepared_data/test/._153236.jpg
#   inflating: large_prepared_data/test/189506.jpg
#   inflating: __MACOSX/large_prepared_data/test/._189506.jpg
#   inflating: large_prepared_data/test/196354.jpg
#   inflating: __MACOSX/large_prepared_data/test/._196354.jpg
#   inflating: large_prepared_data/test/label_df.csv
#   inflating: large_prepared_data/test/022752.jpg
#   inflating: __MACOSX/large_prepared_data/test/._022752.jpg
#   inflating: large_prepared_data/test/001438.jpg
#   inflating: __MACOSX/large_prepared_data/test/._001438.jpg
#   inflating: large_prepared_data/test/189102.jpg
#   inflating: __MACOSX/large_prepared_data/test/._189102.jpg
#   inflating: large_prepared_data/test/016804.jpg
#   inflating: __MACOSX/large_prepared_data/test/._016804.jpg
#   inflating: large_prepared_data/test/138509.jpg
#   inflating: __MACOSX/large_prepared_data/test/._138509.jpg
#   inflating: large_prepared_data/test/097498.jpg
#   inflating: __MACOSX/large_prepared_data/test/._097498.jpg
#   inflating: large_prepared_data/test/190334.jpg
#   inflating: __MACOSX/large_prepared_data/test/._190334.jpg
#   inflating: large_prepared_data/test/136040.jpg
#   inflating: __MACOSX/large_prepared_data/test/._136040.jpg
#   inflating: large_prepared_data/test/201132.jpg
#   inflating: __MACOSX/large_prepared_data/test/._201132.jpg
#   inflating: large_prepared_data/test/186754.jpg
#   inflating: __MACOSX/large_prepared_data/test/._186754.jpg
#   inflating: large_prepared_data/test/112653.jpg
#   inflating: __MACOSX/large_prepared_data/test/._112653.jpg
#   inflating: large_prepared_data/test/125612.jpg
#   inflating: __MACOSX/large_prepared_data/test/._125612.jpg
#   inflating: large_prepared_data/test/164100.jpg
#   inflating: __MACOSX/large_prepared_data/test/._164100.jpg
#   inflating: large_prepared_data/test/143226.jpg
#   inflating: __MACOSX/large_prepared_data/test/._143226.jpg
#   inflating: large_prepared_data/test/108555.jpg
#   inflating: __MACOSX/large_prepared_data/test/._108555.jpg
#   inflating: large_prepared_data/test/162959.jpg
#   inflating: __MACOSX/large_prepared_data/test/._162959.jpg
#   inflating: large_prepared_data/test/176079.jpg
#   inflating: __MACOSX/large_prepared_data/test/._176079.jpg
#   inflating: large_prepared_data/test/190715.jpg
#   inflating: __MACOSX/large_prepared_data/test/._190715.jpg
#   inflating: large_prepared_data/test/113385.jpg
#   inflating: __MACOSX/large_prepared_data/test/._113385.jpg
#   inflating: large_prepared_data/test/169429.jpg
#   inflating: __MACOSX/large_prepared_data/test/._169429.jpg
#   inflating: large_prepared_data/test/122776.jpg
#   inflating: __MACOSX/large_prepared_data/test/._122776.jpg
#   inflating: large_prepared_data/test/085720.jpg
#   inflating: __MACOSX/large_prepared_data/test/._085720.jpg
#   inflating: large_prepared_data/test/039183.jpg
#   inflating: __MACOSX/large_prepared_data/test/._039183.jpg
#   inflating: large_prepared_data/test/048961.jpg
#   inflating: __MACOSX/large_prepared_data/test/._048961.jpg
#   inflating: large_prepared_data/test/116808.jpg
#   inflating: __MACOSX/large_prepared_data/test/._116808.jpg
#   inflating: large_prepared_data/test/199308.jpg
#   inflating: __MACOSX/large_prepared_data/test/._199308.jpg
#   inflating: large_prepared_data/test/159892.jpg
#   inflating: __MACOSX/large_prepared_data/test/._159892.jpg
#   inflating: large_prepared_data/test/017860.jpg
#   inflating: __MACOSX/large_prepared_data/test/._017860.jpg
#   inflating: large_prepared_data/test/092842.jpg
#   inflating: __MACOSX/large_prepared_data/test/._092842.jpg
#   inflating: large_prepared_data/test/186176.jpg
#   inflating: __MACOSX/large_prepared_data/test/._186176.jpg
#   inflating: large_prepared_data/test/068246.jpg
#   inflating: __MACOSX/large_prepared_data/test/._068246.jpg
#   inflating: large_prepared_data/test/199240.jpg
#   inflating: __MACOSX/large_prepared_data/test/._199240.jpg
#   inflating: large_prepared_data/test/121875.jpg
#   inflating: __MACOSX/large_prepared_data/test/._121875.jpg
#   inflating: large_prepared_data/test/167808.jpg
#   inflating: __MACOSX/large_prepared_data/test/._167808.jpg
#   inflating: large_prepared_data/test/024925.jpg
#   inflating: __MACOSX/large_prepared_data/test/._024925.jpg
#   inflating: large_prepared_data/test/193753.jpg
#   inflating: __MACOSX/large_prepared_data/test/._193753.jpg
#   inflating: large_prepared_data/test/138467.jpg
#   inflating: __MACOSX/large_prepared_data/test/._138467.jpg
#   inflating: large_prepared_data/test/179413.jpg
#   inflating: __MACOSX/large_prepared_data/test/._179413.jpg
#   inflating: large_prepared_data/test/187901.jpg
#   inflating: __MACOSX/large_prepared_data/test/._187901.jpg
#   inflating: large_prepared_data/test/040292.jpg
#   inflating: __MACOSX/large_prepared_data/test/._040292.jpg
#   inflating: large_prepared_data/test/146436.jpg
#   inflating: __MACOSX/large_prepared_data/test/._146436.jpg
#   inflating: large_prepared_data/test/089284.jpg
#   inflating: __MACOSX/large_prepared_data/test/._089284.jpg
#   inflating: large_prepared_data/test/153952.jpg
#   inflating: __MACOSX/large_prepared_data/test/._153952.jpg
#   inflating: large_prepared_data/test/043599.jpg
#   inflating: __MACOSX/large_prepared_data/test/._043599.jpg
#   inflating: large_prepared_data/test/050320.jpg
#   inflating: __MACOSX/large_prepared_data/test/._050320.jpg
#   inflating: large_prepared_data/test/195257.jpg
#   inflating: __MACOSX/large_prepared_data/test/._195257.jpg
#   inflating: large_prepared_data/test/005888.jpg
#   inflating: __MACOSX/large_prepared_data/test/._005888.jpg
#   inflating: large_prepared_data/test/121490.jpg
#   inflating: __MACOSX/large_prepared_data/test/._121490.jpg
#   inflating: large_prepared_data/test/009122.jpg
#   inflating: __MACOSX/large_prepared_data/test/._009122.jpg
#   inflating: large_prepared_data/test/017481.jpg
#   inflating: __MACOSX/large_prepared_data/test/._017481.jpg
#   inflating: large_prepared_data/test/122162.jpg
#   inflating: __MACOSX/large_prepared_data/test/._122162.jpg
#   inflating: large_prepared_data/test/199333.jpg
#   inflating: __MACOSX/large_prepared_data/test/._199333.jpg
#   inflating: large_prepared_data/test/177598.jpg
#   inflating: __MACOSX/large_prepared_data/test/._177598.jpg
#   inflating: large_prepared_data/test/013744.jpg
#   inflating: __MACOSX/large_prepared_data/test/._013744.jpg
#   inflating: large_prepared_data/test/151205.jpg
#   inflating: __MACOSX/large_prepared_data/test/._151205.jpg
#   inflating: large_prepared_data/test/136275.jpg
#   inflating: __MACOSX/large_prepared_data/test/._136275.jpg
#   inflating: large_prepared_data/test/127378.jpg
#   inflating: __MACOSX/large_prepared_data/test/._127378.jpg
#   inflating: large_prepared_data/test/105867.jpg
#   inflating: __MACOSX/large_prepared_data/test/._105867.jpg
#   inflating: large_prepared_data/test/158590.jpg
#   inflating: __MACOSX/large_prepared_data/test/._158590.jpg
#   inflating: large_prepared_data/test/197451.jpg
#   inflating: __MACOSX/large_prepared_data/test/._197451.jpg
#   inflating: large_prepared_data/test/151210.jpg
#   inflating: __MACOSX/large_prepared_data/test/._151210.jpg
#   inflating: large_prepared_data/test/171301.jpg
#   inflating: __MACOSX/large_prepared_data/test/._171301.jpg
#   inflating: large_prepared_data/test/193409.jpg
#   inflating: __MACOSX/large_prepared_data/test/._193409.jpg
#   inflating: large_prepared_data/test/102304.jpg
#   inflating: __MACOSX/large_prepared_data/test/._102304.jpg
#   inflating: large_prepared_data/test/101989.jpg
#   inflating: __MACOSX/large_prepared_data/test/._101989.jpg
#   inflating: large_prepared_data/test/015518.jpg
#   inflating: __MACOSX/large_prepared_data/test/._015518.jpg
#   inflating: large_prepared_data/test/043038.jpg
#   inflating: __MACOSX/large_prepared_data/test/._043038.jpg
#   inflating: large_prepared_data/test/185862.jpg
#   inflating: __MACOSX/large_prepared_data/test/._185862.jpg
#   inflating: large_prepared_data/test/171061.jpg
#   inflating: __MACOSX/large_prepared_data/test/._171061.jpg
#   inflating: large_prepared_data/test/112288.jpg
#   inflating: __MACOSX/large_prepared_data/test/._112288.jpg
#   inflating: large_prepared_data/test/172959.jpg
#   inflating: __MACOSX/large_prepared_data/test/._172959.jpg
#   inflating: large_prepared_data/test/161845.jpg
#   inflating: __MACOSX/large_prepared_data/test/._161845.jpg
#   inflating: large_prepared_data/test/156227.jpg
#   inflating: __MACOSX/large_prepared_data/test/._156227.jpg
#   inflating: large_prepared_data/test/176690.jpg
#   inflating: __MACOSX/large_prepared_data/test/._176690.jpg
#   inflating: large_prepared_data/test/164294.jpg
#   inflating: __MACOSX/large_prepared_data/test/._164294.jpg
#   inflating: large_prepared_data/test/163712.jpg
#   inflating: __MACOSX/large_prepared_data/test/._163712.jpg
#   inflating: large_prepared_data/test/150482.jpg
#   inflating: __MACOSX/large_prepared_data/test/._150482.jpg
#   inflating: large_prepared_data/test/081032.jpg
#   inflating: __MACOSX/large_prepared_data/test/._081032.jpg
#   inflating: large_prepared_data/test/087457.jpg
#   inflating: __MACOSX/large_prepared_data/test/._087457.jpg
#   inflating: large_prepared_data/test/189446.jpg
#   inflating: __MACOSX/large_prepared_data/test/._189446.jpg
#   inflating: large_prepared_data/test/130564.jpg
#   inflating: __MACOSX/large_prepared_data/test/._130564.jpg
#   inflating: large_prepared_data/test/186365.jpg
#   inflating: __MACOSX/large_prepared_data/test/._186365.jpg
#   inflating: large_prepared_data/test/171921.jpg
#   inflating: __MACOSX/large_prepared_data/test/._171921.jpg
#   inflating: large_prepared_data/test/014607.jpg
#   inflating: __MACOSX/large_prepared_data/test/._014607.jpg
#   inflating: large_prepared_data/test/110348.jpg
#   inflating: __MACOSX/large_prepared_data/test/._110348.jpg
#   inflating: large_prepared_data/test/112205.jpg
#   inflating: __MACOSX/large_prepared_data/test/._112205.jpg
#   inflating: large_prepared_data/test/077310.jpg
#   inflating: __MACOSX/large_prepared_data/test/._077310.jpg
#   inflating: large_prepared_data/test/118933.jpg
#   inflating: __MACOSX/large_prepared_data/test/._118933.jpg
#   inflating: large_prepared_data/test/022305.jpg
#   inflating: __MACOSX/large_prepared_data/test/._022305.jpg
#   inflating: large_prepared_data/test/150234.jpg
#   inflating: __MACOSX/large_prepared_data/test/._150234.jpg
#   inflating: large_prepared_data/test/163761.jpg
#   inflating: __MACOSX/large_prepared_data/test/._163761.jpg
#   inflating: large_prepared_data/test/032089.jpg
#   inflating: __MACOSX/large_prepared_data/test/._032089.jpg
#   inflating: large_prepared_data/test/081257.jpg
#   inflating: __MACOSX/large_prepared_data/test/._081257.jpg
#   inflating: large_prepared_data/test/186262.jpg
#   inflating: __MACOSX/large_prepared_data/test/._186262.jpg
#   inflating: large_prepared_data/test/167063.jpg
#   inflating: __MACOSX/large_prepared_data/test/._167063.jpg
#   inflating: large_prepared_data/test/029330.jpg
#   inflating: __MACOSX/large_prepared_data/test/._029330.jpg
#   inflating: large_prepared_data/test/169066.jpg
#   inflating: __MACOSX/large_prepared_data/test/._169066.jpg
#   inflating: large_prepared_data/test/038572.jpg
#   inflating: __MACOSX/large_prepared_data/test/._038572.jpg
#   inflating: large_prepared_data/test/167089.jpg
#   inflating: __MACOSX/large_prepared_data/test/._167089.jpg
#   inflating: large_prepared_data/test/010765.jpg
#   inflating: __MACOSX/large_prepared_data/test/._010765.jpg
#   inflating: large_prepared_data/test/180404.jpg
#   inflating: __MACOSX/large_prepared_data/test/._180404.jpg
#   inflating: large_prepared_data/test/179894.jpg
#   inflating: __MACOSX/large_prepared_data/test/._179894.jpg
#   inflating: large_prepared_data/test/182818.jpg
#   inflating: __MACOSX/large_prepared_data/test/._182818.jpg
#   inflating: large_prepared_data/test/202050.jpg
#   inflating: __MACOSX/large_prepared_data/test/._202050.jpg
#   inflating: large_prepared_data/test/157980.jpg
#   inflating: __MACOSX/large_prepared_data/test/._157980.jpg
#   inflating: large_prepared_data/test/162913.jpg
#   inflating: __MACOSX/large_prepared_data/test/._162913.jpg
#   inflating: large_prepared_data/test/184502.jpg
#   inflating: __MACOSX/large_prepared_data/test/._184502.jpg
#   inflating: large_prepared_data/test/163372.jpg
#   inflating: __MACOSX/large_prepared_data/test/._163372.jpg
#   inflating: large_prepared_data/test/182826.jpg
#   inflating: __MACOSX/large_prepared_data/test/._182826.jpg
#   inflating: large_prepared_data/test/073607.jpg
#   inflating: __MACOSX/large_prepared_data/test/._073607.jpg
#   inflating: large_prepared_data/test/113871.jpg
#   inflating: __MACOSX/large_prepared_data/test/._113871.jpg
#   inflating: large_prepared_data/test/147763.jpg
#   inflating: __MACOSX/large_prepared_data/test/._147763.jpg
#   inflating: large_prepared_data/test/166961.jpg
#   inflating: __MACOSX/large_prepared_data/test/._166961.jpg
#   inflating: large_prepared_data/test/196270.jpg
#   inflating: __MACOSX/large_prepared_data/test/._196270.jpg
#   inflating: large_prepared_data/test/179060.jpg
#   inflating: __MACOSX/large_prepared_data/test/._179060.jpg
#   inflating: large_prepared_data/test/178829.jpg
#   inflating: __MACOSX/large_prepared_data/test/._178829.jpg
#   inflating: large_prepared_data/test/103243.jpg
#   inflating: __MACOSX/large_prepared_data/test/._103243.jpg
#   inflating: large_prepared_data/test/110217.jpg
#   inflating: __MACOSX/large_prepared_data/test/._110217.jpg
#   inflating: large_prepared_data/test/144684.jpg
#   inflating: __MACOSX/large_prepared_data/test/._144684.jpg
#   inflating: large_prepared_data/test/093692.jpg
#   inflating: __MACOSX/large_prepared_data/test/._093692.jpg
#   inflating: large_prepared_data/test/077070.jpg
#   inflating: __MACOSX/large_prepared_data/test/._077070.jpg
#   inflating: large_prepared_data/test/199142.jpg
#   inflating: __MACOSX/large_prepared_data/test/._199142.jpg
#   inflating: large_prepared_data/test/101119.jpg
#   inflating: __MACOSX/large_prepared_data/test/._101119.jpg
#   inflating: large_prepared_data/test/086062.jpg
#   inflating: __MACOSX/large_prepared_data/test/._086062.jpg
#   inflating: large_prepared_data/test/101131.jpg
#   inflating: __MACOSX/large_prepared_data/test/._101131.jpg
#   inflating: large_prepared_data/test/055574.jpg
#   inflating: __MACOSX/large_prepared_data/test/._055574.jpg
#   inflating: large_prepared_data/test/135323.jpg
#   inflating: __MACOSX/large_prepared_data/test/._135323.jpg
#   inflating: large_prepared_data/test/171207.jpg
#   inflating: __MACOSX/large_prepared_data/test/._171207.jpg
#   inflating: large_prepared_data/test/133975.jpg
#   inflating: __MACOSX/large_prepared_data/test/._133975.jpg
#   inflating: large_prepared_data/test/174394.jpg
#   inflating: __MACOSX/large_prepared_data/test/._174394.jpg
#   inflating: large_prepared_data/test/123743.jpg
#   inflating: __MACOSX/large_prepared_data/test/._123743.jpg
#   inflating: large_prepared_data/test/041129.jpg
#   inflating: __MACOSX/large_prepared_data/test/._041129.jpg
#   inflating: large_prepared_data/test/001257.jpg
#   inflating: __MACOSX/large_prepared_data/test/._001257.jpg
#   inflating: large_prepared_data/test/088117.jpg
#   inflating: __MACOSX/large_prepared_data/test/._088117.jpg
#   inflating: large_prepared_data/test/195152.jpg
#   inflating: __MACOSX/large_prepared_data/test/._195152.jpg
#   inflating: large_prepared_data/test/174409.jpg
#   inflating: __MACOSX/large_prepared_data/test/._174409.jpg
#   inflating: large_prepared_data/test/166384.jpg
#   inflating: __MACOSX/large_prepared_data/test/._166384.jpg
#   inflating: large_prepared_data/test/137691.jpg
#   inflating: __MACOSX/large_prepared_data/test/._137691.jpg
#   inflating: large_prepared_data/test/124174.jpg
#   inflating: __MACOSX/large_prepared_data/test/._124174.jpg
#   inflating: large_prepared_data/test/062647.jpg
#   inflating: __MACOSX/large_prepared_data/test/._062647.jpg
#   inflating: large_prepared_data/test/044858.jpg
#   inflating: __MACOSX/large_prepared_data/test/._044858.jpg
#   inflating: large_prepared_data/test/027441.jpg
#   inflating: __MACOSX/large_prepared_data/test/._027441.jpg
#   inflating: large_prepared_data/test/033384.jpg
#   inflating: __MACOSX/large_prepared_data/test/._033384.jpg
#   inflating: large_prepared_data/test/006698.jpg
#   inflating: __MACOSX/large_prepared_data/test/._006698.jpg
#   inflating: large_prepared_data/test/193442.jpg
#   inflating: __MACOSX/large_prepared_data/test/._193442.jpg
#   inflating: large_prepared_data/test/174597.jpg
#   inflating: __MACOSX/large_prepared_data/test/._174597.jpg
#   inflating: large_prepared_data/test/113322.jpg
#   inflating: __MACOSX/large_prepared_data/test/._113322.jpg
#   inflating: large_prepared_data/test/190003.jpg
#   inflating: __MACOSX/large_prepared_data/test/._190003.jpg
#   inflating: large_prepared_data/test/163376.jpg
#   inflating: __MACOSX/large_prepared_data/test/._163376.jpg
#   inflating: large_prepared_data/test/155177.jpg
#   inflating: __MACOSX/large_prepared_data/test/._155177.jpg
#   inflating: large_prepared_data/test/201213.jpg
#   inflating: __MACOSX/large_prepared_data/test/._201213.jpg
#   inflating: large_prepared_data/test/128163.jpg
#   inflating: __MACOSX/large_prepared_data/test/._128163.jpg
#   inflating: large_prepared_data/test/165063.jpg
#   inflating: __MACOSX/large_prepared_data/test/._165063.jpg
#   inflating: large_prepared_data/test/168976.jpg
#   inflating: __MACOSX/large_prepared_data/test/._168976.jpg
#   inflating: large_prepared_data/test/095804.jpg
#   inflating: __MACOSX/large_prepared_data/test/._095804.jpg
#   inflating: large_prepared_data/test/167310.jpg
#   inflating: __MACOSX/large_prepared_data/test/._167310.jpg
#   inflating: large_prepared_data/test/142999.jpg
#   inflating: __MACOSX/large_prepared_data/test/._142999.jpg
#   inflating: large_prepared_data/test/164751.jpg
#   inflating: __MACOSX/large_prepared_data/test/._164751.jpg
#   inflating: large_prepared_data/test/090834.jpg
#   inflating: __MACOSX/large_prepared_data/test/._090834.jpg
#   inflating: large_prepared_data/test/199435.jpg
#   inflating: __MACOSX/large_prepared_data/test/._199435.jpg
#   inflating: large_prepared_data/test/169739.jpg
#   inflating: __MACOSX/large_prepared_data/test/._169739.jpg
#   inflating: large_prepared_data/test/177260.jpg
#   inflating: __MACOSX/large_prepared_data/test/._177260.jpg
#   inflating: large_prepared_data/test/185960.jpg
#   inflating: __MACOSX/large_prepared_data/test/._185960.jpg
#   inflating: large_prepared_data/test/187150.jpg
#   inflating: __MACOSX/large_prepared_data/test/._187150.jpg
#   inflating: large_prepared_data/test/116891.jpg
#   inflating: __MACOSX/large_prepared_data/test/._116891.jpg
#   inflating: large_prepared_data/test/178423.jpg
#   inflating: __MACOSX/large_prepared_data/test/._178423.jpg
#   inflating: large_prepared_data/test/019750.jpg
#   inflating: __MACOSX/large_prepared_data/test/._019750.jpg
#   inflating: large_prepared_data/test/169328.jpg
#   inflating: __MACOSX/large_prepared_data/test/._169328.jpg
#   inflating: large_prepared_data/test/141315.jpg
#   inflating: __MACOSX/large_prepared_data/test/._141315.jpg
#   inflating: large_prepared_data/test/194058.jpg
#   inflating: __MACOSX/large_prepared_data/test/._194058.jpg
#   inflating: large_prepared_data/test/071942.jpg
#   inflating: __MACOSX/large_prepared_data/test/._071942.jpg
#   inflating: large_prepared_data/train/108526.jpg
#   inflating: __MACOSX/large_prepared_data/train/._108526.jpg
#   inflating: large_prepared_data/train/008240.jpg
#   inflating: __MACOSX/large_prepared_data/train/._008240.jpg
#   inflating: large_prepared_data/train/146675.jpg
#   inflating: __MACOSX/large_prepared_data/train/._146675.jpg
#   inflating: large_prepared_data/train/154271.jpg
#   inflating: __MACOSX/large_prepared_data/train/._154271.jpg
#   inflating: large_prepared_data/train/196130.jpg
#   inflating: __MACOSX/large_prepared_data/train/._196130.jpg
#   inflating: large_prepared_data/train/182623.jpg
#   inflating: __MACOSX/large_prepared_data/train/._182623.jpg
#   inflating: large_prepared_data/train/045397.jpg
#   inflating: __MACOSX/large_prepared_data/train/._045397.jpg
#   inflating: large_prepared_data/train/175532.jpg
#   inflating: __MACOSX/large_prepared_data/train/._175532.jpg
#   inflating: large_prepared_data/train/090582.jpg
#   inflating: __MACOSX/large_prepared_data/train/._090582.jpg
#   inflating: large_prepared_data/train/172275.jpg
#   inflating: __MACOSX/large_prepared_data/train/._172275.jpg
#   inflating: large_prepared_data/train/164371.jpg
#   inflating: __MACOSX/large_prepared_data/train/._164371.jpg
#   inflating: large_prepared_data/train/029517.jpg
#   inflating: __MACOSX/large_prepared_data/train/._029517.jpg
#   inflating: large_prepared_data/train/079446.jpg
#   inflating: __MACOSX/large_prepared_data/train/._079446.jpg
#   inflating: large_prepared_data/train/110382.jpg
#   inflating: __MACOSX/large_prepared_data/train/._110382.jpg
#   inflating: large_prepared_data/train/176588.jpg
#   inflating: __MACOSX/large_prepared_data/train/._176588.jpg
#   inflating: large_prepared_data/train/155351.jpg
#   inflating: __MACOSX/large_prepared_data/train/._155351.jpg
#   inflating: large_prepared_data/train/170847.jpg
#   inflating: __MACOSX/large_prepared_data/train/._170847.jpg
#   inflating: large_prepared_data/train/034963.jpg
#   inflating: __MACOSX/large_prepared_data/train/._034963.jpg
#   inflating: large_prepared_data/train/071581.jpg
#   inflating: __MACOSX/large_prepared_data/train/._071581.jpg
#   inflating: large_prepared_data/train/117176.jpg
#   inflating: __MACOSX/large_prepared_data/train/._117176.jpg
#   inflating: large_prepared_data/train/156664.jpg
#   inflating: __MACOSX/large_prepared_data/train/._156664.jpg
#   inflating: large_prepared_data/train/086121.jpg
#   inflating: __MACOSX/large_prepared_data/train/._086121.jpg
#   inflating: large_prepared_data/train/112998.jpg
#   inflating: __MACOSX/large_prepared_data/train/._112998.jpg
#   inflating: large_prepared_data/train/092140.jpg
#   inflating: __MACOSX/large_prepared_data/train/._092140.jpg
#   inflating: large_prepared_data/train/088118.jpg
#   inflating: __MACOSX/large_prepared_data/train/._088118.jpg
#   inflating: large_prepared_data/train/013338.jpg
#   inflating: __MACOSX/large_prepared_data/train/._013338.jpg
#   inflating: large_prepared_data/train/052364.jpg
#   inflating: __MACOSX/large_prepared_data/train/._052364.jpg
#   inflating: large_prepared_data/train/141481.jpg
#   inflating: __MACOSX/large_prepared_data/train/._141481.jpg
#   inflating: large_prepared_data/train/054932.jpg
#   inflating: __MACOSX/large_prepared_data/train/._054932.jpg
#   inflating: large_prepared_data/train/181869.jpg
#   inflating: __MACOSX/large_prepared_data/train/._181869.jpg
#   inflating: large_prepared_data/train/120731.jpg
#   inflating: __MACOSX/large_prepared_data/train/._120731.jpg
#   inflating: large_prepared_data/train/039512.jpg
#   inflating: __MACOSX/large_prepared_data/train/._039512.jpg
#   inflating: large_prepared_data/train/188865.jpg
#   inflating: __MACOSX/large_prepared_data/train/._188865.jpg
#   inflating: large_prepared_data/train/194294.jpg
#   inflating: __MACOSX/large_prepared_data/train/._194294.jpg
#   inflating: large_prepared_data/train/027738.jpg
#   inflating: __MACOSX/large_prepared_data/train/._027738.jpg
#   inflating: large_prepared_data/train/032453.jpg
#   inflating: __MACOSX/large_prepared_data/train/._032453.jpg
#   inflating: large_prepared_data/train/087411.jpg
#   inflating: __MACOSX/large_prepared_data/train/._087411.jpg
#   inflating: large_prepared_data/train/142759.jpg
#   inflating: __MACOSX/large_prepared_data/train/._142759.jpg
#   inflating: large_prepared_data/train/168198.jpg
#   inflating: __MACOSX/large_prepared_data/train/._168198.jpg
#   inflating: large_prepared_data/train/158729.jpg
#   inflating: __MACOSX/large_prepared_data/train/._158729.jpg
#   inflating: large_prepared_data/train/005348.jpg
#   inflating: __MACOSX/large_prepared_data/train/._005348.jpg
#   inflating: large_prepared_data/train/122085.jpg
#   inflating: __MACOSX/large_prepared_data/train/._122085.jpg
#   inflating: large_prepared_data/train/172659.jpg
#   inflating: __MACOSX/large_prepared_data/train/._172659.jpg
#   inflating: large_prepared_data/train/072895.jpg
#   inflating: __MACOSX/large_prepared_data/train/._072895.jpg
#   inflating: large_prepared_data/train/138988.jpg
#   inflating: __MACOSX/large_prepared_data/train/._138988.jpg
#   inflating: large_prepared_data/train/028225.jpg
#   inflating: __MACOSX/large_prepared_data/train/._028225.jpg
#   inflating: large_prepared_data/train/086900.jpg
#   inflating: __MACOSX/large_prepared_data/train/._086900.jpg
#   inflating: large_prepared_data/train/088905.jpg
#   inflating: __MACOSX/large_prepared_data/train/._088905.jpg
#   inflating: large_prepared_data/train/176403.jpg
#   inflating: __MACOSX/large_prepared_data/train/._176403.jpg
#   inflating: large_prepared_data/train/022046.jpg
#   inflating: __MACOSX/large_prepared_data/train/._022046.jpg
#   inflating: large_prepared_data/train/004095.jpg
#   inflating: __MACOSX/large_prepared_data/train/._004095.jpg
#   inflating: large_prepared_data/train/033639.jpg
#   inflating: __MACOSX/large_prepared_data/train/._033639.jpg
#   inflating: large_prepared_data/train/199439.jpg
#   inflating: __MACOSX/large_prepared_data/train/._199439.jpg
#   inflating: large_prepared_data/train/095565.jpg
#   inflating: __MACOSX/large_prepared_data/train/._095565.jpg
#   inflating: large_prepared_data/train/179297.jpg
#   inflating: __MACOSX/large_prepared_data/train/._179297.jpg
#   inflating: large_prepared_data/train/193896.jpg
#   inflating: __MACOSX/large_prepared_data/train/._193896.jpg
#   inflating: large_prepared_data/train/056274.jpg
#   inflating: __MACOSX/large_prepared_data/train/._056274.jpg
#   inflating: large_prepared_data/train/169090.jpg
#   inflating: __MACOSX/large_prepared_data/train/._169090.jpg
#   inflating: large_prepared_data/train/110235.jpg
#   inflating: __MACOSX/large_prepared_data/train/._110235.jpg
#   inflating: large_prepared_data/train/123827.jpg
#   inflating: __MACOSX/large_prepared_data/train/._123827.jpg
#   inflating: large_prepared_data/train/128027.jpg
#   inflating: __MACOSX/large_prepared_data/train/._128027.jpg
#   inflating: large_prepared_data/train/016863.jpg
#   inflating: __MACOSX/large_prepared_data/train/._016863.jpg
#   inflating: large_prepared_data/train/037649.jpg
#   inflating: __MACOSX/large_prepared_data/train/._037649.jpg
#   inflating: large_prepared_data/train/166412.jpg
#   inflating: __MACOSX/large_prepared_data/train/._166412.jpg
#   inflating: large_prepared_data/train/129311.jpg
#   inflating: __MACOSX/large_prepared_data/train/._129311.jpg
#   inflating: large_prepared_data/train/087820.jpg
#   inflating: __MACOSX/large_prepared_data/train/._087820.jpg
#   inflating: large_prepared_data/train/074017.jpg
#   inflating: __MACOSX/large_prepared_data/train/._074017.jpg
#   inflating: large_prepared_data/train/129462.jpg
#   inflating: __MACOSX/large_prepared_data/train/._129462.jpg
#   inflating: large_prepared_data/train/105836.jpg
#   inflating: __MACOSX/large_prepared_data/train/._105836.jpg
#   inflating: large_prepared_data/train/151297.jpg
#   inflating: __MACOSX/large_prepared_data/train/._151297.jpg
#   inflating: large_prepared_data/train/174981.jpg
#   inflating: __MACOSX/large_prepared_data/train/._174981.jpg
#   inflating: large_prepared_data/train/043687.jpg
#   inflating: __MACOSX/large_prepared_data/train/._043687.jpg
#   inflating: large_prepared_data/train/109942.jpg
#   inflating: __MACOSX/large_prepared_data/train/._109942.jpg
#   inflating: large_prepared_data/train/041084.jpg
#   inflating: __MACOSX/large_prepared_data/train/._041084.jpg
#   inflating: large_prepared_data/train/075447.jpg
#   inflating: __MACOSX/large_prepared_data/train/._075447.jpg
#   inflating: large_prepared_data/train/087809.jpg
#   inflating: __MACOSX/large_prepared_data/train/._087809.jpg
#   inflating: large_prepared_data/train/072328.jpg
#   inflating: __MACOSX/large_prepared_data/train/._072328.jpg
#   inflating: large_prepared_data/train/084333.jpg
#   inflating: __MACOSX/large_prepared_data/train/._084333.jpg
#   inflating: large_prepared_data/train/056513.jpg
#   inflating: __MACOSX/large_prepared_data/train/._056513.jpg
#   inflating: large_prepared_data/train/085987.jpg
#   inflating: __MACOSX/large_prepared_data/train/._085987.jpg
#   inflating: large_prepared_data/train/180169.jpg
#   inflating: __MACOSX/large_prepared_data/train/._180169.jpg
#   inflating: large_prepared_data/train/141053.jpg
#   inflating: __MACOSX/large_prepared_data/train/._141053.jpg
#   inflating: large_prepared_data/train/162852.jpg
#   inflating: __MACOSX/large_prepared_data/train/._162852.jpg
#   inflating: large_prepared_data/train/179043.jpg
#   inflating: __MACOSX/large_prepared_data/train/._179043.jpg
#   inflating: large_prepared_data/train/187389.jpg
#   inflating: __MACOSX/large_prepared_data/train/._187389.jpg
#   inflating: large_prepared_data/train/165318.jpg
#   inflating: __MACOSX/large_prepared_data/train/._165318.jpg
#   inflating: large_prepared_data/train/053866.jpg
#   inflating: __MACOSX/large_prepared_data/train/._053866.jpg
#   inflating: large_prepared_data/train/174573.jpg
#   inflating: __MACOSX/large_prepared_data/train/._174573.jpg
#   inflating: large_prepared_data/train/168172.jpg
#   inflating: __MACOSX/large_prepared_data/train/._168172.jpg
#   inflating: large_prepared_data/train/172894.jpg
#   inflating: __MACOSX/large_prepared_data/train/._172894.jpg
#   inflating: large_prepared_data/train/167527.jpg
#   inflating: __MACOSX/large_prepared_data/train/._167527.jpg
#   inflating: large_prepared_data/train/175889.jpg
#   inflating: __MACOSX/large_prepared_data/train/._175889.jpg
#   inflating: large_prepared_data/train/176358.jpg
#   inflating: __MACOSX/large_prepared_data/train/._176358.jpg
#   inflating: large_prepared_data/train/186732.jpg
#   inflating: __MACOSX/large_prepared_data/train/._186732.jpg
#   inflating: large_prepared_data/train/180343.jpg
#   inflating: __MACOSX/large_prepared_data/train/._180343.jpg
#   inflating: large_prepared_data/train/109201.jpg
#   inflating: __MACOSX/large_prepared_data/train/._109201.jpg
#   inflating: large_prepared_data/train/107238.jpg
#   inflating: __MACOSX/large_prepared_data/train/._107238.jpg
#   inflating: large_prepared_data/train/010750.jpg
#   inflating: __MACOSX/large_prepared_data/train/._010750.jpg
#   inflating: large_prepared_data/train/138976.jpg
#   inflating: __MACOSX/large_prepared_data/train/._138976.jpg
#   inflating: large_prepared_data/train/177091.jpg
#   inflating: __MACOSX/large_prepared_data/train/._177091.jpg
#   inflating: large_prepared_data/train/073585.jpg
#   inflating: __MACOSX/large_prepared_data/train/._073585.jpg
#   inflating: large_prepared_data/train/098242.jpg
#   inflating: __MACOSX/large_prepared_data/train/._098242.jpg
#   inflating: large_prepared_data/train/134816.jpg
#   inflating: __MACOSX/large_prepared_data/train/._134816.jpg
#   inflating: large_prepared_data/train/055556.jpg
#   inflating: __MACOSX/large_prepared_data/train/._055556.jpg
#   inflating: large_prepared_data/train/195000.jpg
#   inflating: __MACOSX/large_prepared_data/train/._195000.jpg
#   inflating: large_prepared_data/train/151863.jpg
#   inflating: __MACOSX/large_prepared_data/train/._151863.jpg
#   inflating: large_prepared_data/train/176204.jpg
#   inflating: __MACOSX/large_prepared_data/train/._176204.jpg
#   inflating: large_prepared_data/train/179137.jpg
#   inflating: __MACOSX/large_prepared_data/train/._179137.jpg
#   inflating: large_prepared_data/train/035329.jpg
#   inflating: __MACOSX/large_prepared_data/train/._035329.jpg
#   inflating: large_prepared_data/train/166003.jpg
#   inflating: __MACOSX/large_prepared_data/train/._166003.jpg
#   inflating: large_prepared_data/train/138619.jpg
#   inflating: __MACOSX/large_prepared_data/train/._138619.jpg
#   inflating: large_prepared_data/train/170649.jpg
#   inflating: __MACOSX/large_prepared_data/train/._170649.jpg
#   inflating: large_prepared_data/train/004862.jpg
#   inflating: __MACOSX/large_prepared_data/train/._004862.jpg
#   inflating: large_prepared_data/train/151687.jpg
#   inflating: __MACOSX/large_prepared_data/train/._151687.jpg
#   inflating: large_prepared_data/train/075725.jpg
#   inflating: __MACOSX/large_prepared_data/train/._075725.jpg
#   inflating: large_prepared_data/train/092627.jpg
#   inflating: __MACOSX/large_prepared_data/train/._092627.jpg
#   inflating: large_prepared_data/train/177867.jpg
#   inflating: __MACOSX/large_prepared_data/train/._177867.jpg
#   inflating: large_prepared_data/train/096455.jpg
#   inflating: __MACOSX/large_prepared_data/train/._096455.jpg
#   inflating: large_prepared_data/train/112027.jpg
#   inflating: __MACOSX/large_prepared_data/train/._112027.jpg
#   inflating: large_prepared_data/train/175902.jpg
# ...
#   inflating: large_prepared_data/val/060141.jpg
#   inflating: __MACOSX/large_prepared_data/val/._060141.jpg
#   inflating: large_prepared_data/val/111551.jpg
#   inflating: __MACOSX/large_prepared_data/val/._111551.jpg
#   inflating: large_prepared_data/val/125186.jpg
#   inflating: __MACOSX/large_prepared_data/val/._125186.jpg
#   inflating: large_prepared_data/val/197132.jpg
#   inflating: __MACOSX/large_prepared_data/val/._197132.jpg
#   inflating: large_prepared_data/val/022762.jpg
#   inflating: __MACOSX/large_prepared_data/val/._022762.jpg
#   inflating: large_prepared_data/val/202152.jpg
#   inflating: __MACOSX/large_prepared_data/val/._202152.jpg
#   inflating: large_prepared_data/val/011182.jpg
#   inflating: __MACOSX/large_prepared_data/val/._011182.jpg
#   inflating: large_prepared_data/val/005690.jpg
#   inflating: __MACOSX/large_prepared_data/val/._005690.jpg
#   inflating: large_prepared_data/val/001421.jpg
#   inflating: __MACOSX/large_prepared_data/val/._001421.jpg
#   inflating: large_prepared_data/val/042915.jpg
#   inflating: __MACOSX/large_prepared_data/val/._042915.jpg
#   inflating: large_prepared_data/val/053617.jpg
#   inflating: __MACOSX/large_prepared_data/val/._053617.jpg
#   inflating: large_prepared_data/val/139579.jpg
#   inflating: __MACOSX/large_prepared_data/val/._139579.jpg
#   inflating: large_prepared_data/val/192467.jpg
#   inflating: __MACOSX/large_prepared_data/val/._192467.jpg
#   inflating: large_prepared_data/val/045465.jpg
#   inflating: __MACOSX/large_prepared_data/val/._045465.jpg
#   inflating: large_prepared_data/val/141173.jpg
#   inflating: __MACOSX/large_prepared_data/val/._141173.jpg
#   inflating: large_prepared_data/val/105731.jpg
#   inflating: __MACOSX/large_prepared_data/val/._105731.jpg
#   inflating: large_prepared_data/val/105057.jpg
#   inflating: __MACOSX/large_prepared_data/val/._105057.jpg
#   inflating: large_prepared_data/val/020994.jpg
#   inflating: __MACOSX/large_prepared_data/val/._020994.jpg
#   inflating: large_prepared_data/val/009241.jpg
#   inflating: __MACOSX/large_prepared_data/val/._009241.jpg
#   inflating: large_prepared_data/val/040872.jpg
#   inflating: __MACOSX/large_prepared_data/val/._040872.jpg
#   inflating: large_prepared_data/val/085284.jpg
#   inflating: __MACOSX/large_prepared_data/val/._085284.jpg
#   inflating: large_prepared_data/val/065370.jpg
#   inflating: __MACOSX/large_prepared_data/val/._065370.jpg
#   inflating: large_prepared_data/val/014748.jpg
#   inflating: __MACOSX/large_prepared_data/val/._014748.jpg
#   inflating: large_prepared_data/val/104567.jpg
#   inflating: __MACOSX/large_prepared_data/val/._104567.jpg
#   inflating: large_prepared_data/val/156547.jpg
#   inflating: __MACOSX/large_prepared_data/val/._156547.jpg
#   inflating: large_prepared_data/val/004201.jpg
#   inflating: __MACOSX/large_prepared_data/val/._004201.jpg
#   inflating: large_prepared_data/val/127433.jpg
#   inflating: __MACOSX/large_prepared_data/val/._127433.jpg
#   inflating: large_prepared_data/val/022984.jpg
#   inflating: __MACOSX/large_prepared_data/val/._022984.jpg
#   inflating: large_prepared_data/val/090139.jpg
#   inflating: __MACOSX/large_prepared_data/val/._090139.jpg
#   inflating: large_prepared_data/val/038328.jpg
#   inflating: __MACOSX/large_prepared_data/val/._038328.jpg
#   inflating: large_prepared_data/val/050902.jpg
#   inflating: __MACOSX/large_prepared_data/val/._050902.jpg
#   inflating: large_prepared_data/val/089722.jpg
#   inflating: __MACOSX/large_prepared_data/val/._089722.jpg
#   inflating: large_prepared_data/val/040522.jpg
#   inflating: __MACOSX/large_prepared_data/val/._040522.jpg
#   inflating: large_prepared_data/val/155665.jpg
#   inflating: __MACOSX/large_prepared_data/val/._155665.jpg
#   inflating: large_prepared_data/val/105734.jpg
#   inflating: __MACOSX/large_prepared_data/val/._105734.jpg
#   inflating: large_prepared_data/val/132167.jpg
#   inflating: __MACOSX/large_prepared_data/val/._132167.jpg
#   inflating: large_prepared_data/val/054962.jpg
#   inflating: __MACOSX/large_prepared_data/val/._054962.jpg
#   inflating: large_prepared_data/val/187455.jpg
#   inflating: __MACOSX/large_prepared_data/val/._187455.jpg
#   inflating: large_prepared_data/val/038258.jpg
#   inflating: __MACOSX/large_prepared_data/val/._038258.jpg
#   inflating: large_prepared_data/val/117251.jpg
#   inflating: __MACOSX/large_prepared_data/val/._117251.jpg
#   inflating: large_prepared_data/val/150126.jpg
#   inflating: __MACOSX/large_prepared_data/val/._150126.jpg
#   inflating: large_prepared_data/val/076268.jpg
#   inflating: __MACOSX/large_prepared_data/val/._076268.jpg
#   inflating: large_prepared_data/val/006770.jpg
#   inflating: __MACOSX/large_prepared_data/val/._006770.jpg
#   inflating: large_prepared_data/val/036114.jpg
#   inflating: __MACOSX/large_prepared_data/val/._036114.jpg
#   inflating: large_prepared_data/val/135353.jpg
#   inflating: __MACOSX/large_prepared_data/val/._135353.jpg
#   inflating: large_prepared_data/val/183618.jpg
#   inflating: __MACOSX/large_prepared_data/val/._183618.jpg
#   inflating: large_prepared_data/val/104993.jpg
#   inflating: __MACOSX/large_prepared_data/val/._104993.jpg
#   inflating: large_prepared_data/val/065148.jpg
#   inflating: __MACOSX/large_prepared_data/val/._065148.jpg
#   inflating: large_prepared_data/val/131243.jpg
#   inflating: __MACOSX/large_prepared_data/val/._131243.jpg
#   inflating: large_prepared_data/val/040487.jpg
#   inflating: __MACOSX/large_prepared_data/val/._040487.jpg
#   inflating: large_prepared_data/val/122216.jpg
#   inflating: __MACOSX/large_prepared_data/val/._122216.jpg
#   inflating: large_prepared_data/val/001342.jpg
#   inflating: __MACOSX/large_prepared_data/val/._001342.jpg
#   inflating: large_prepared_data/val/049460.jpg
#   inflating: __MACOSX/large_prepared_data/val/._049460.jpg
#   inflating: large_prepared_data/val/018439.jpg
#   inflating: __MACOSX/large_prepared_data/val/._018439.jpg
#   inflating: large_prepared_data/val/149676.jpg
#   inflating: __MACOSX/large_prepared_data/val/._149676.jpg
#   inflating: large_prepared_data/val/039385.jpg
#   inflating: __MACOSX/large_prepared_data/val/._039385.jpg
#   inflating: large_prepared_data/val/140915.jpg
#   inflating: __MACOSX/large_prepared_data/val/._140915.jpg
#   inflating: large_prepared_data/val/019874.jpg
#   inflating: __MACOSX/large_prepared_data/val/._019874.jpg
#   inflating: large_prepared_data/val/011582.jpg
#   inflating: __MACOSX/large_prepared_data/val/._011582.jpg
#   inflating: large_prepared_data/val/120763.jpg
#   inflating: __MACOSX/large_prepared_data/val/._120763.jpg
#   inflating: large_prepared_data/val/079164.jpg
#   inflating: __MACOSX/large_prepared_data/val/._079164.jpg
#   inflating: large_prepared_data/val/119135.jpg
#   inflating: __MACOSX/large_prepared_data/val/._119135.jpg
#   inflating: large_prepared_data/val/015218.jpg
#   inflating: __MACOSX/large_prepared_data/val/._015218.jpg
#   inflating: large_prepared_data/val/200120.jpg
#   inflating: __MACOSX/large_prepared_data/val/._200120.jpg
#   inflating: large_prepared_data/val/028358.jpg
#   inflating: __MACOSX/large_prepared_data/val/._028358.jpg
#   inflating: large_prepared_data/val/077099.jpg
#   inflating: __MACOSX/large_prepared_data/val/._077099.jpg
#   inflating: large_prepared_data/val/152769.jpg
#   inflating: __MACOSX/large_prepared_data/val/._152769.jpg
#   inflating: large_prepared_data/val/007998.jpg
#   inflating: __MACOSX/large_prepared_data/val/._007998.jpg
#   inflating: large_prepared_data/val/148725.jpg
#   inflating: __MACOSX/large_prepared_data/val/._148725.jpg
#   inflating: large_prepared_data/val/194128.jpg
#   inflating: __MACOSX/large_prepared_data/val/._194128.jpg
#   inflating: large_prepared_data/val/021750.jpg
#   inflating: __MACOSX/large_prepared_data/val/._021750.jpg
#   inflating: large_prepared_data/val/069066.jpg
#   inflating: __MACOSX/large_prepared_data/val/._069066.jpg
#   inflating: large_prepared_data/val/085965.jpg
#   inflating: __MACOSX/large_prepared_data/val/._085965.jpg
#   inflating: large_prepared_data/val/000984.jpg
#   inflating: __MACOSX/large_prepared_data/val/._000984.jpg
#   inflating: large_prepared_data/val/186908.jpg
#   inflating: __MACOSX/large_prepared_data/val/._186908.jpg
#   inflating: large_prepared_data/val/052230.jpg
#   inflating: __MACOSX/large_prepared_data/val/._052230.jpg
#   inflating: large_prepared_data/val/132473.jpg
#   inflating: __MACOSX/large_prepared_data/val/._132473.jpg
#   inflating: large_prepared_data/val/114852.jpg
#   inflating: __MACOSX/large_prepared_data/val/._114852.jpg
#   inflating: large_prepared_data/val/059761.jpg
#   inflating: __MACOSX/large_prepared_data/val/._059761.jpg
#   inflating: large_prepared_data/val/086303.jpg
#   inflating: __MACOSX/large_prepared_data/val/._086303.jpg
#   inflating: large_prepared_data/val/141660.jpg
#   inflating: __MACOSX/large_prepared_data/val/._141660.jpg
#   inflating: large_prepared_data/val/129253.jpg
#   inflating: __MACOSX/large_prepared_data/val/._129253.jpg
#   inflating: large_prepared_data/val/038955.jpg
#   inflating: __MACOSX/large_prepared_data/val/._038955.jpg
#   inflating: large_prepared_data/val/052226.jpg
#   inflating: __MACOSX/large_prepared_data/val/._052226.jpg
#   inflating: large_prepared_data/val/076409.jpg
#   inflating: __MACOSX/large_prepared_data/val/._076409.jpg
#   inflating: large_prepared_data/val/008464.jpg
#   inflating: __MACOSX/large_prepared_data/val/._008464.jpg
#   inflating: large_prepared_data/val/063212.jpg
#   inflating: __MACOSX/large_prepared_data/val/._063212.jpg
#   inflating: large_prepared_data/val/134362.jpg
#   inflating: __MACOSX/large_prepared_data/val/._134362.jpg
#   inflating: large_prepared_data/val/201361.jpg
#   inflating: __MACOSX/large_prepared_data/val/._201361.jpg
#   inflating: large_prepared_data/val/060726.jpg
#   inflating: __MACOSX/large_prepared_data/val/._060726.jpg
#   inflating: large_prepared_data/val/121746.jpg
#   inflating: __MACOSX/large_prepared_data/val/._121746.jpg
#   inflating: large_prepared_data/val/110558.jpg
#   inflating: __MACOSX/large_prepared_data/val/._110558.jpg
#   inflating: large_prepared_data/val/047825.jpg
#   inflating: __MACOSX/large_prepared_data/val/._047825.jpg
#   inflating: large_prepared_data/val/147819.jpg
#   inflating: __MACOSX/large_prepared_data/val/._147819.jpg
#   inflating: large_prepared_data/val/137454.jpg
#   inflating: __MACOSX/large_prepared_data/val/._137454.jpg
#   inflating: large_prepared_data/val/096271.jpg
#   inflating: __MACOSX/large_prepared_data/val/._096271.jpg
#   inflating: large_prepared_data/val/073404.jpg
#   inflating: __MACOSX/large_prepared_data/val/._073404.jpg
#   inflating: large_prepared_data/val/189225.jpg
#   inflating: __MACOSX/large_prepared_data/val/._189225.jpg
#   inflating: large_prepared_data/val/140582.jpg
#   inflating: __MACOSX/large_prepared_data/val/._140582.jpg
#   inflating: large_prepared_data/val/122313.jpg
#   inflating: __MACOSX/large_prepared_data/val/._122313.jpg
#   inflating: large_prepared_data/val/035647.jpg
#   inflating: __MACOSX/large_prepared_data/val/._035647.jpg
#   inflating: large_prepared_data/val/042424.jpg
#   inflating: __MACOSX/large_prepared_data/val/._042424.jpg
#   inflating: large_prepared_data/val/159969.jpg
#   inflating: __MACOSX/large_prepared_data/val/._159969.jpg
#   inflating: large_prepared_data/val/027521.jpg
#   inflating: __MACOSX/large_prepared_data/val/._027521.jpg
#   inflating: large_prepared_data/val/068544.jpg
#   inflating: __MACOSX/large_prepared_data/val/._068544.jpg
#   inflating: large_prepared_data/val/050965.jpg
#   inflating: __MACOSX/large_prepared_data/val/._050965.jpg
#   inflating: large_prepared_data/val/008703.jpg
#   inflating: __MACOSX/large_prepared_data/val/._008703.jpg
#   inflating: large_prepared_data/val/157207.jpg
#   inflating: __MACOSX/large_prepared_data/val/._157207.jpg
#   inflating: large_prepared_data/val/127079.jpg
#   inflating: __MACOSX/large_prepared_data/val/._127079.jpg
#   inflating: large_prepared_data/val/190957.jpg
#   inflating: __MACOSX/large_prepared_data/val/._190957.jpg
#   inflating: large_prepared_data/val/045993.jpg
#   inflating: __MACOSX/large_prepared_data/val/._045993.jpg
#   inflating: large_prepared_data/val/020845.jpg
#   inflating: __MACOSX/large_prepared_data/val/._020845.jpg
#   inflating: large_prepared_data/val/106896.jpg
#   inflating: __MACOSX/large_prepared_data/val/._106896.jpg
#   inflating: large_prepared_data/val/202447.jpg
#   inflating: __MACOSX/large_prepared_data/val/._202447.jpg
#   inflating: large_prepared_data/val/160093.jpg
#   inflating: __MACOSX/large_prepared_data/val/._160093.jpg
#   inflating: large_prepared_data/val/049429.jpg
#   inflating: __MACOSX/large_prepared_data/val/._049429.jpg
#   inflating: large_prepared_data/val/154479.jpg
#   inflating: __MACOSX/large_prepared_data/val/._154479.jpg
#   inflating: large_prepared_data/val/023342.jpg
#   inflating: __MACOSX/large_prepared_data/val/._023342.jpg
#   inflating: large_prepared_data/val/012160.jpg
#   inflating: __MACOSX/large_prepared_data/val/._012160.jpg
#   inflating: large_prepared_data/val/131626.jpg
#   inflating: __MACOSX/large_prepared_data/val/._131626.jpg
#   inflating: large_prepared_data/val/099796.jpg
#   inflating: __MACOSX/large_prepared_data/val/._099796.jpg
#   inflating: large_prepared_data/val/106061.jpg
#   inflating: __MACOSX/large_prepared_data/val/._106061.jpg
#   inflating: large_prepared_data/val/162068.jpg
#   inflating: __MACOSX/large_prepared_data/val/._162068.jpg
#   inflating: large_prepared_data/val/064394.jpg
#   inflating: __MACOSX/large_prepared_data/val/._064394.jpg
#   inflating: large_prepared_data/val/151885.jpg
#   inflating: __MACOSX/large_prepared_data/val/._151885.jpg
#   inflating: large_prepared_data/val/042609.jpg
#   inflating: __MACOSX/large_prepared_data/val/._042609.jpg
#   inflating: large_prepared_data/val/029057.jpg
#   inflating: __MACOSX/large_prepared_data/val/._029057.jpg
#   inflating: large_prepared_data/val/082565.jpg
#   inflating: __MACOSX/large_prepared_data/val/._082565.jpg
#   inflating: large_prepared_data/val/153670.jpg
#   inflating: __MACOSX/large_prepared_data/val/._153670.jpg
#   inflating: large_prepared_data/val/090149.jpg
#   inflating: __MACOSX/large_prepared_data/val/._090149.jpg
#   inflating: large_prepared_data/val/055573.jpg
#   inflating: __MACOSX/large_prepared_data/val/._055573.jpg
#   inflating: large_prepared_data/val/023368.jpg
#   inflating: __MACOSX/large_prepared_data/val/._023368.jpg
#   inflating: large_prepared_data/val/002601.jpg
#   inflating: __MACOSX/large_prepared_data/val/._002601.jpg
#   inflating: large_prepared_data/val/040383.jpg
#   inflating: __MACOSX/large_prepared_data/val/._040383.jpg
#   inflating: large_prepared_data/val/193865.jpg
#   inflating: __MACOSX/large_prepared_data/val/._193865.jpg
#   inflating: large_prepared_data/val/185949.jpg
#   inflating: __MACOSX/large_prepared_data/val/._185949.jpg
#   inflating: large_prepared_data/val/025533.jpg
#   inflating: __MACOSX/large_prepared_data/val/._025533.jpg
#   inflating: large_prepared_data/val/015142.jpg
#   inflating: __MACOSX/large_prepared_data/val/._015142.jpg
#   inflating: large_prepared_data/val/055200.jpg
#   inflating: __MACOSX/large_prepared_data/val/._055200.jpg
#   inflating: large_prepared_data/val/081858.jpg
#   inflating: __MACOSX/large_prepared_data/val/._081858.jpg
#   inflating: large_prepared_data/val/084934.jpg
#   inflating: __MACOSX/large_prepared_data/val/._084934.jpg
#   inflating: large_prepared_data/val/031157.jpg
#   inflating: __MACOSX/large_prepared_data/val/._031157.jpg
#   inflating: large_prepared_data/val/012981.jpg
#   inflating: __MACOSX/large_prepared_data/val/._012981.jpg
#   inflating: large_prepared_data/val/149211.jpg
#   inflating: __MACOSX/large_prepared_data/val/._149211.jpg

# %% [markdown]
# # Common dataset

# %%
class FaceDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.label_df = pd.read_csv(f"{self.root_dir}/label_df.csv")

    def __len__(self):
        return len(self.label_df)

    def __getitem__(self, idx):
        data = self.label_df.iloc[idx]
        img = Image.open(f"{self.root_dir}/{data['filename']}").convert("RGB")
        if self.transform is not None:
            transformed_img = self.transform(img)
        else:
            transformed_img = None
        identity = data["identity"]
        return transformed_img, identity, np.array(img)

# %% [markdown]
# This is an example to display a face image with its identity

# %%
import matplotlib.pyplot as plt

face_dataset = FaceDataset(root_dir="large_prepared_data/test")

for idx in range(4):
    _, identity, img = face_dataset[idx]
    plt.title(f"identity = {identity}")
    plt.imshow(img)
    plt.show()

# %% [markdown]
# # Part 1: Face verification with contrastive loss
#
# The objective of the face verification task is to validate whether the face image $x$ has the identity $y$ by comparing it to the face database of the claimed identity. If the face similarity score between $x$ and the face in the database of $y$ is above a certain threshold, the image is then verified; otherwise, the identity is rejected.
#
# In HW3, you have learned to calculate a similarity score based on compact image representation using a PCA / Fisher projection. Therefore, in this part, you will instead implement a more contemporary method by training the NN to propose a compact representation (feature vector) by using a Siamese network and contrastive loss (Chopra et al., 2005, https://ieeexplore.ieee.org/stamp/stamp.jsp?tp=&arnumber=1467314).
#
# In contrast to the classification task that forces the model to learn all possible classes of objects, the general idea of object verification is based on contrastive learning, a framework that teaches the model to distinguish the two objects from each other. For a contrastive loss, the model will receive a pair of image and then learn to recognize whether both of them has the same identity by encouraging the feature vector of the same identity to come closer and different one to move away from each other.

# %% [markdown]
# ## 1.1 (TODO) Dataset and DataLoader
#
# First, we will start by writing a dataloader. The contrastive loss learns whether a pair of images have the same identity. Therefore, in this subsection, you have to write a dataloader that returns the tuple `(img1, img2, is_same_identity (bool))`.
#
# **File structure of this dataset**
#
# ```
# - large_prepared_data/
# └───train/
# |    - {img1}.jpg
# |    - {img2}.jpg
# |    - label_df.csv
# └───val/
# |    - {img3}.jpg
# |    - {img4}.jpg
# |    - label_df.csv
# └───test/
#     - {img5}.jpg
#     - {img6}.jpg
#     - label_df.csv
# ```
#
# **Note**
#
# label_df.csv has 2 columns that are the filename such as 001257.jpg and the identity such as 1691
#
# **Instructions**
#
# TODO 1-4: Fill in the missing code in the cells below. \
# TODO 1-2: Organize the dataset for simple data access. \
# TODO 3: Randomly select the datapoint from the dataset and format it to be ready for training. \
# TODO 4: Initialize the dataloader.

# %%
class SiameseDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        """
        The dataset of siamese network
        [Args]
        - root_dir = root directory of the dataset
        - transform = transformations for images
        """
        np.random.seed(123)
        random.seed(123)
        self.root_dir = root_dir
        self.transform = transform
        label_df = pd.read_csv(f"{root_dir}/label_df.csv")
        self.num_images = len(label_df)
        label_df = (
            label_df.groupby("identity")["filename"]
            .apply(list)
            .reset_index()
            .rename({"filename": "filenames"}, axis=1)
        )
        self.load_images_to_memory_(label_df)

    def load_images_to_memory_(self, label_df):
        """
        Load all images into memory
        [Args]
        - label_df = The dataframe containing the identities and the filenames of images
        """
        # TODO 1: load images to `self.data` according to the below structure
        # and `self.images`, `self.identities` following by idx
        # Note: identity{i}: str, image{i}: PIL.Image (convert them to RGB as well)
        # e.g. self.data = {
        #   'identity1': [image1, image2],
        #   'identity2': [image3, image4, image5],
        # }
        #
        # identity{i}: str, image{i}: PIL.Image
        self.data = {}
        self.img = {}
        self.identities = {}
        for idx in tqdm(range(len(label_df)), desc="Loading images to memory"):
            row = label_df.iloc[idx]
            identity, filenames = row["identity"], row["filenames"]

            self.data[identity] = [
                Image.open(f"{self.root_dir}/{filename}").convert("RGB")
                for filename in filenames
            ]
            self.img[identity] = [self.transform(img) for img in self.data[identity]]
            self.identities[idx] = identity

        # TODO 2: keep all unique identities as list with `self.unique_identities`
        # in `self.unique_identities` as a numpy array.
        self.unique_identities = np.array(list(self.data.keys()))

    def __len__(self):
        return self.num_images

    def __getitem__(self, idx):
        """
        Return a pair of image together with its label
        [Args]
        - idx: int
        [Return]
        - img1: torch.FloatTensor
        - img2: torch.FloatTensor
        - label: torch.FloatTensor = 1 (same class), 0 (different class)
        """
        # TODO 3: randomly sample a pair of images
        # Note: idx is even, it should return the same class pair and otherwise
        # Please use label = 1 for the same class pair
        # and label = 0 for the different class pair
        unique_identities_list = list(self.unique_identities)
        if idx % 2 == 0:
            # Same class pair
            identity = random.choice(unique_identities_list)
            images = self.data[identity]
            img1, img2 = random.sample(images, 2)
            label = 1
        else:
            # Different class pair
            identity1, identity2 = random.sample(unique_identities_list, 2)
            while identity1 == identity2:
                identity1, identity2 = random.sample(unique_identities_list, 2)
            img1 = random.choice(self.data[identity1])
            img2 = random.choice(self.data[identity2])
            label = 0
        if self.transform is not None:
            img1 = self.transform(img1)
            img2 = self.transform(img2)

        return img1, img2, torch.from_numpy(np.array([label], dtype=np.float32))

# %%
img_size = 224
train_transform = transforms.Compose(
    [
        transforms.Resize((256, 256)),
        transforms.CenterCrop(img_size),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.ToTensor(),
        transforms.Normalize(
            mean=[0.5319, 0.4399, 0.3929], std=[0.3076, 0.2898, 0.2907]
        ),
    ]
)

val_transform = transforms.Compose(
    [
        transforms.Resize((256, 256)),
        transforms.CenterCrop(img_size),
        transforms.ToTensor(),
        transforms.Normalize(
            mean=[0.5319, 0.4399, 0.3929], std=[0.3076, 0.2898, 0.2907]
        ),
    ]
)

train_batch_size = 16
val_batch_size = 16
test_batch_size = 16


# TODO 4: declare the datasets and the dataloaders
train_siamese_dataset = SiameseDataset(
    root_dir="large_prepared_data/train", transform=train_transform
)
train_siamese_dataloader = DataLoader(
    train_siamese_dataset, batch_size=train_batch_size, shuffle=True
)

val_siamese_dataset = SiameseDataset(
    root_dir="large_prepared_data/val", transform=val_transform
)
val_siamese_dataloader = DataLoader(
    val_siamese_dataset, batch_size=val_batch_size, shuffle=False
)

test_siamese_dataset = SiameseDataset(
    root_dir="large_prepared_data/test", transform=val_transform
)
test_siamese_dataloader = DataLoader(
    test_siamese_dataset, batch_size=test_batch_size, shuffle=False
)
# Out:
# Loading images to memory:   0%|          | 0/80 [00:00<?, ?it/s]
# Loading images to memory:   0%|          | 0/10 [00:00<?, ?it/s]
# Loading images to memory:   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# ## 1.2 (TODO) Siamese network
#
# After the dataloader is initialized, we then build a siamese network. Section 1.5 will explain how a siamese network works in full detail.
#
# Siamese network is a typical CNN that consists of three modules:
#
# 1. A feature extractor (ResNet18) for extracting the feature map from an image.
# 2. A global pooling for reducing the image dimension.
# 3. A fully connected layer for compressing the feature vector
#
# Every fully connected layer is followed by ReLU activations.
#
# TODO 5: Implement a siamese network based on the description.
#
# **Note**
#
# 1. You can use the ResNet18 from the `torchvision` library (How to use torchvision: https://pytorch.org/vision/stable/models.html)
# 2. We will not use pretrained weights.

# %% [markdown]
# Figure 1 Siamese network
#
# ![Screen Shot 2565-03-31 at 16.23.59.png](data:image/png;base64,...)

# %%
from torchvision import models

# %%
class SiameseNetwork(nn.Module):
    # TODO 5: implement the siamese network
    def __init__(self):
        super().__init__()
        self.resnet18 = models.resnet18(weights=None)

        self.pool = nn.AdaptiveAvgPool1d(512)
        self.fc1 = nn.Linear(512, 256)
        self.fc2 = nn.Linear(256, 128)

    def extract_feature(self, x):
        x = self.resnet18(x)
        x = self.pool(x)
        x = F.relu(self.fc1(x))
        output = F.relu(self.fc2(x))
        return output

    def forward(self, input1, input2):
        feat1 = self.extract_feature(input1)
        feat2 = self.extract_feature(input2)
        return feat1, feat2

# %% [markdown]
# ## 1.3 (TODO) Constrastive loss
#
# A contrastive loss is a loss used to minimize the dissimilarity between two images by encouraging the feature vector of the same identity to come closer and different one further than a constant margin $m$ to move away from each other.
#
# The contrastive loss is mathematically defined as:

# %% [markdown]
# $
# L\ (contrastive\ loss ) = \begin{cases}
#                         d(r_1, r_2) & if\ identity(r1) = identity(r2) \\
#                         max(0, m - d(r_1, r_2)) & if\ identity(r1) \neq identity(r2) \\
#                     \end{cases}
# \
# $

# %% [markdown]
# where
#
# - $d(r_1, r_2)$ = euclidean distance between $r_1$ and $r_2$
# - $m$ = margin
# - $identity(x)$ = the identity of x
# - $r_1$ = the feature vector of the first image
# - $r_2$ = the feature vector of the second image

# %% [markdown]
# The term $d(r_1, r_2)$ is the distance between the two feature vectors. The contrastive loss minimizes the distance between the feature vectors of the same identity (positive pair) but maximizes the distance of the different identities (negative pair).
#
# The margin $m$ is used to prevent the loss from collapsing to a trivial solution. For instance, when $m = 0$, the model could achieve $L = 0$ just by exploiting the objective by setting $r_1 = r_2$, and the model, as a result, would learn nothing useful.
#
# **HINT**
#
# Many torch functions often have the same functionality as NumPy functions, even sharing the same function name. Therefore, if you are struggling with this part, you might write the loss using NumPy first and then convert it to the torch function (https://pytorch.org/docs/stable/torch.html) later.
# **Avoid using "if statements" to make the training faster. You have already learned many tricks that convert if statements into a single equation.**

# %% [markdown]
# TODO 6: Implement a contrastive loss based on the description above.

# %%
import torch
from torch import nn
import torch.nn.functional as F

class ContrastiveLoss(torch.nn.Module):
    # TODO 6: implement the contrastive loss
    def __init__(self, margin):
        super().__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        # Calculate Euclidean distance
        distance = F.pairwise_distance(output1, output2, keepdim=True)
        
        # When label == 1 (same identity), we minimize the distance
        # When label == 0 (different identity), we maximize distance up to the margin
        # We square the terms which is the standard Hadsell Contrastive Loss formulation
        loss_contrastive = torch.mean(
            label * distance + 
            (1 - label) * torch.clamp(self.margin - distance, min=0.0)
        )
        
        return loss_contrastive

# %% [markdown]
# ## 1.4 Initiazing the model, criterion, optimizer and scheduler

# %%
siamese_margin = 2
learning_rate = 1e-4

siamese_model = SiameseNetwork()
siamese_criterion = ContrastiveLoss(margin=siamese_margin)
siamese_optimizer = optim.Adam(siamese_model.parameters(), lr=learning_rate)
siamese_scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    siamese_optimizer, "min", patience=5, factor=0.1, min_lr=1e-8
)

# %% [markdown]
# ## 1.5 (TODO) Training loop
#
# The training procedure of a siamese network consists of the following steps:
#
# 1. Forward pass the `img1`.
# 2. Forward pass the `img2`.
# 3. Calculate the distance between the feature vector of `img1` and `img2` $(d(r_1, r_2))$.
# 4. Use the distance in step 3 as a loss and update the model.
# 5. Repeat step 1-4 until satisfied.
#
# As you would notice, both first and second step shares the same network weights. Therefore, the word "Siamese" in the siamese network originates from the "Siamese twins" since the network performs two forward passes to compare whether the feature vectors have the same identity by using the same set of network parameters (shared parameters).
#
# TODO 7-8: Feed pairs of images to the network, compute contrastive loss to measure the dissimilarity of pairs of face images and update the network.
#
# TODO 9: Feed a pair of images from validation set to the network and compute the validation loss.
#
# **Trivia**
#
# The Siamese twin is a conjoined twin brother born in Siam who later move to the US (https://th.wikipedia.org/wiki/%E0%B8%AD%E0%B8%B4%E0%B8%99-%E0%B8%88%E0%B8%B1%E0%B8%99).

# %%
num_epochs = 20
device = "cuda" if torch.cuda.is_available() else "cpu"
siamese_model.to(device)

os.makedirs("weights", exist_ok=True)
best_weights_path = "weights/best_siamese_weights.pth"

train_losses = []
val_losses = []
min_val_loss = float("inf")

for epoch in tqdm(range(num_epochs)):
    siamese_model.train()
    total_train_loss = 0

    for img1, img2, label in tqdm(train_siamese_dataloader):
        
        # Move tensors to the configured device
        img1, img2, label = img1.to(device), img2.to(device), label.to(device)

        # TODO 7: feed data to model and compute loss
        siamese_optimizer.zero_grad()
        
        feat1, feat2 = siamese_model(img1, img2)
        train_loss = siamese_criterion(feat1, feat2, label)
        
        # TODO 8: back propagate
        train_loss.backward()
        siamese_optimizer.step()

        total_train_loss += train_loss.item()

    current_train_loss = total_train_loss / len(train_siamese_dataloader)
    train_losses.append(current_train_loss)

    total_val_loss = 0
    siamese_model.eval()
    
    # Validation shouldn't track gradients
    with torch.no_grad():
        for val_img1, val_img2, val_label in val_siamese_dataloader:

            # Move tensors to the configured device
            val_img1, val_img2, val_label = val_img1.to(device), val_img2.to(device), val_label.to(device)

            # TODO 9: feed data to model and compute loss
            val_feat1, val_feat2 = siamese_model(val_img1, val_img2)
            val_loss = siamese_criterion(val_feat1, val_feat2, val_label)

            total_val_loss += val_loss.item()
            
    current_val_loss = total_val_loss / len(val_siamese_dataloader)
    val_losses.append(current_val_loss)
    if current_val_loss < min_val_loss:
        min_val_loss = current_val_loss
        torch.save(siamese_model.state_dict(), best_weights_path)
    print(
        f'Epoch {epoch+1} - Train loss = {current_train_loss:.4f} - Val loss = {current_val_loss:.4f} - best min_val_loss = {min_val_loss:.4f} - lr = {siamese_optimizer.param_groups[0]["lr"]:.8f}'
    )
    siamese_scheduler.step(current_val_loss)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/153 [00:00<?, ?it/s]
# Epoch 1 - Train loss = 0.8756 - Val loss = 0.7972 - best min_val_loss = 0.7972 - lr = 0.00010000
#   0%|          | 0/153 [00:00<?, ?it/s]
# Epoch 2 - Train loss = 0.8392 - Val loss = 0.7479 - best min_val_loss = 0.7479 - lr = 0.00010000
#   0%|          | 0/153 [00:00<?, ?it/s]
# Epoch 3 - Train loss = 0.8195 - Val loss = 0.7242 - best min_val_loss = 0.7242 - lr = 0.00010000
#   0%|          | 0/153 [00:00<?, ?it/s]
# Epoch 4 - Train loss = 0.8125 - Val loss = 0.7704 - best min_val_loss = 0.7242 - lr = 0.00010000
#   0%|          | 0/153 [00:00<?, ?it/s]
# Epoch 5 - Train loss = 0.8133 - Val loss = 0.7989 - best min_val_loss = 0.7242 - lr = 0.00010000
#   0%|          | 0/153 [00:00<?, ?it/s]
# Epoch 6 - Train loss = 0.7984 - Val loss = 0.9996 - best min_val_loss = 0.7242 - lr = 0.00010000
#   0%|          | 0/153 [00:00<?, ?it/s]
# Epoch 7 - Train loss = 0.8283 - Val loss = 0.8656 - best min_val_loss = 0.7242 - lr = 0.00010000
#   0%|          | 0/153 [00:00<?, ?it/s]
# Epoch 8 - Train loss = 0.7902 - Val loss = 0.8319 - best min_val_loss = 0.7242 - lr = 0.00010000
#   0%|          | 0/153 [00:00<?, ?it/s]
# Epoch 9 - Train loss = 0.7807 - Val loss = 0.6857 - best min_val_loss = 0.6857 - lr = 0.00010000
#   0%|          | 0/153 [00:00<?, ?it/s]
# Epoch 10 - Train loss = 0.7629 - Val loss = 0.7956 - best min_val_loss = 0.6857 - lr = 0.00010000
#   0%|          | 0/153 [00:00<?, ?it/s]
# Epoch 11 - Train loss = 0.7857 - Val loss = 0.7082 - best min_val_loss = 0.6857 - lr = 0.00010000
#   0%|          | 0/153 [00:00<?, ?it/s]
# Epoch 12 - Train loss = 0.8119 - Val loss = 0.7579 - best min_val_loss = 0.6857 - lr = 0.00010000
#   0%|          | 0/153 [00:00<?, ?it/s]
# Epoch 13 - Train loss = 0.7700 - Val loss = 0.7773 - best min_val_loss = 0.6857 - lr = 0.00010000
#   0%|          | 0/153 [00:00<?, ?it/s]
# Epoch 14 - Train loss = 0.7607 - Val loss = 0.7608 - best min_val_loss = 0.6857 - lr = 0.00010000
#   0%|          | 0/153 [00:00<?, ?it/s]
# Epoch 15 - Train loss = 0.7505 - Val loss = 0.7118 - best min_val_loss = 0.6857 - lr = 0.00010000
#   0%|          | 0/153 [00:00<?, ?it/s]
# Epoch 16 - Train loss = 0.7098 - Val loss = 0.6715 - best min_val_loss = 0.6715 - lr = 0.00001000
#   0%|          | 0/153 [00:00<?, ?it/s]
# Epoch 17 - Train loss = 0.7023 - Val loss = 0.6784 - best min_val_loss = 0.6715 - lr = 0.00001000
#   0%|          | 0/153 [00:00<?, ?it/s]
# Epoch 18 - Train loss = 0.7059 - Val loss = 0.7409 - best min_val_loss = 0.6715 - lr = 0.00001000
#   0%|          | 0/153 [00:00<?, ?it/s]
# Epoch 19 - Train loss = 0.6901 - Val loss = 0.6428 - best min_val_loss = 0.6428 - lr = 0.00001000
#   0%|          | 0/153 [00:00<?, ?it/s]
# Epoch 20 - Train loss = 0.7033 - Val loss = 0.6121 - best min_val_loss = 0.6121 - lr = 0.00001000

# %% [markdown]
# ## 1.6 Visualization
#
# This visualization displays pairs of images together with the distance between those pairs.

# %%
# Showing images
def imshow(img, text=None):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(
            120,
            8,
            text,
            style="italic",
            fontweight="bold",
            bbox={"facecolor": "white", "alpha": 0.8, "pad": 10},
        )

    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


siamese_model.load_state_dict(torch.load(best_weights_path))
siamese_model.eval()

test_img1s, test_img2s, test_labels = next(iter(test_siamese_dataloader))
test_img1s, test_img2s, test_labels = (
    test_img1s.to(device),
    test_img2s.to(device),
    test_labels.to(device),
)
with torch.no_grad():
    test_out1s, test_out2s = siamese_model(test_img1s, test_img2s)


class UnNormalize(object):
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std

    def __call__(self, tensor):
        """
        Args:
            tensor (Tensor): Tensor image of size (C, H, W) to be normalized.
        Returns:
            Tensor: Normalized image.
        """
        for t, m, s in zip(tensor, self.mean, self.std):
            t.mul_(s).add_(m)
            # The normalize code -> t.sub_(m).div_(s)
        return tensor


unnormalizer = UnNormalize(mean=[0.5319, 0.4399, 0.3929], std=[0.3076, 0.2898, 0.2907])

for test_out1, test_out2, test_img1, test_img2, test_label in zip(
    test_out1s, test_out2s, test_img1s, test_img2s, test_labels
):
    test_img1 = unnormalizer(test_img1.detach().cpu().unsqueeze(0))
    test_img2 = unnormalizer(test_img2.detach().cpu().unsqueeze(0))
    concatenated = torch.cat((test_img1, test_img2), 0)
    distance = F.pairwise_distance(test_out1.unsqueeze(0), test_out2.unsqueeze(0))
    imshow(
        torchvision.utils.make_grid(concatenated),
        f"Label = {int(test_label[0])}, Distance: {distance.item():.4f}",
    )
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.1742941].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.1742941].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0639658].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.1742941].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.1742941].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.1203499].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.1742941].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.1701446].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.1327987].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.1742941].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.1701446].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.1742941].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.1742941].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.1742941].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.1576958].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.1742941].

# %% [markdown]
# ## 1.7 Plot loss history

# %%
plt.plot(np.arange(1, len(train_losses) + 1), train_losses, label="train loss")
plt.plot(np.arange(1, len(val_losses) + 1), val_losses, label="val loss")
plt.legend()
plt.show()

# %% [markdown]
# ## 1.8 (TODO) Plot t-SNE
#
# After the training process is finished, we evaluate whether the learned representation is informative. In this task, embedding visualization is often performed to verify that the feature learned by the network is behaving as intended, i.e., feature vectors of the same identity should be close to each other and far away from other identities. Since the feature vector dimension is too high for a human to interpret, therefore, in this assignment, we use the t-SNE dimensionality reduction technique to compress the feature into a 2D space.
#
# **Instructions**
#
# TODO 10: Extract the feature vectors of the test set and store them as
#
# `embeddings`: torch.FloatTensor = feature vectors of all images in the test set
#
# `identities`: list or torch.Tensor or np.array = identities of all images in the test set
#
# **Hint**
# Use `FaceDataset` that is imported at `Common Dataset` section
#
# **WARNING!!**
# Don't forget load its best weights and change to eval mode first

# %%
test_batch_size = 32

# TODO 10: Extract the feature vectors of the test set and store them as
# `embeddings`: torch.FloatTensor = feature vectors of all images in the test set
# `identities`: list or torch.Tensor or np.array = identities of all images in the test set
# Hint      => Use `FaceDataset` that is imported at `Common Dataset` section
# WARNING!! => Don't forget load its best weights and change to eval mode first

test_dataset = FaceDataset(root_dir="large_prepared_data/test", transform=val_transform)
test_loader = DataLoader(test_dataset, batch_size=test_batch_size)

siamese_model.load_state_dict(torch.load('weights/best_siamese_weights.pth', map_location=device))
siamese_model.eval()

all_embeddings = []
all_identities = []

with torch.no_grad():
    for transformed_img, identity, _ in tqdm(test_loader):
        # Move images to GPU/CPU
        transformed_img = transformed_img.to(device)

        # 3. FORWARD PASS: This converts [32, 3, 224, 224] -> [32, 128]
        features = siamese_model.extract_feature(transformed_img)

        # Store as CPU tensors or numpy
        all_embeddings.append(features.cpu())

        # Identity might be a tensor or list depending on your Dataset
        if torch.is_tensor(identity):
            all_identities.append(identity.cpu())
        else:
            all_identities.extend(identity)
            
embeddings = torch.cat(all_embeddings)
if torch.is_tensor(all_identities[0]):
    identities = torch.cat(all_identities)
else:
    identities = all_identities
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
import time
from sklearn.manifold import TSNE

time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=30, max_iter=3000)
tsne_result = tsne.fit_transform(embeddings, identities)
print("t-SNE done! Time elapsed: {} seconds".format(time.time() - time_start))
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 301 samples in 0.000s...
# [t-SNE] Computed neighbors for 301 samples in 0.005s...
# [t-SNE] Computed conditional probabilities for sample 301 / 301
# [t-SNE] Mean sigma: 0.003280
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 46.750168
# [t-SNE] KL divergence after 2500 iterations: 0.206578
# t-SNE done! Time elapsed: 0.8835434913635254 seconds

# %%
import plotly.express as px

# relabel to be easier to see in t-SNE visualization
label = []
idx = 0
id2label = dict()
for identity in identities:
    identity = int(identity)
    if identity not in id2label:
        id2label[identity] = idx
        idx += 1
    label.append(id2label[identity])

df_subset = pd.DataFrame({"label": label})

df_subset["tsne-2d-one"] = tsne_result[:, 0]
df_subset["tsne-2d-two"] = tsne_result[:, 1]

fig = px.scatter(
    df_subset, x="tsne-2d-one", y="tsne-2d-two", color="label", height=1000, width=1000
)
fig.show()

# %% [markdown]
# ## 1.9 (TODO) Analyzing feature vector visualization result

# %% [markdown]
# TODO 11: What could you say about the displayed visualization? Is the model working as expected?
#
# Answer here: No there is no obvious cluster from tsne visualization.

# %% [markdown]
# # Part 2: Face verification with triplet loss + center loss
#
# In contrast to contrastive loss which learns to distinguish whether the two images have the same identity, triplet loss is proposed as an alternative by introducing an anchor image as a third input. Triplet loss receives three inputs: anchor, positive pair, and negative pair. The positive pair is an image having the same identity as the anchor while the negative pair is the one with a different identity. The loss learns to minimize the distance between the anchor and positive pair, and maximize the distance between the anchor and the negative pair. Compared to contrastive loss, triplet loss offers more training stability and better model performance.
#
# Nevertheless, both contrastive and triplet loss also has some shortcomings as these losses only optimize on a pairwise level. This might result in feature vectors of the same identity taking the form of multiple small clusters scattering across the feature space since there is no explicit loss to bind them into a single group. Therefore, a center loss is proposed to mitigate this problem by encouraging the intra-class (same identity) feature vectors to come closer to their intra-class centroids.
#
# In this part, you are going to implement a face verification network by jointly training **three losses**: triplet, center, and cross-entropy loss.

# %% [markdown]
# ## 2.1 Dataset and DataLoader
#
# In this section, you are going to implement a dataloader for the combined loss.
# The dataloader should return the tuple `(anchor_img, pos_img, neg_img, anchor_label, pos_label, neg_label)`.
#
# - The positive image must have the same identity as the anchor image.
# - The negative image must have a different identity from the anchor image.

# %%
class TripletDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        np.random.seed(123)
        random.seed(123)
        self.root_dir = root_dir
        self.transform = transform

        label_df = pd.read_csv(f"{root_dir}/label_df.csv")
        label_df = (
            label_df.groupby("identity")["filename"]
            .apply(list)
            .reset_index()
            .rename({"filename": "filenames"}, axis=1)
        )
        self.images = []
        self.labels = []
        self.label2indices = dict()
        self.load_images_to_memory_(label_df)

    def load_images_to_memory_(self, label_df):
        # load images and labels into memory
        # We have to relabel from identities to 0,1,2,...,num_classes-1
        # Relevant variables
        # 1. `self.images` = PIL images  (Also convert it to RGB)
        # 2. `self.label2indices` = the dictionary storing a label as a key and the indices of images as value
        # 3. `self.labels` = labels of images (relabeled)
        # Note: the index of images is from iterating over label_df
        self.images = []
        self.label2indices = defaultdict(list)
        self.labels = []
        img_idx = 0
        label_idx = 0
        identity2label = dict()
        for idx in tqdm(range(len(label_df))):
            row = label_df.iloc[idx]
            identity, filenames = row["identity"], row["filenames"]

            if identity not in identity2label:
                identity2label[identity] = label_idx
                label_idx += 1

            label = identity2label[identity]

            for filename in filenames:
                self.images.append(
                    Image.open(f"{self.root_dir}/{filename}").convert("RGB")
                )
                self.labels.append(label)
                self.label2indices[label].append(img_idx)
                img_idx += 1

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        # generate an anchor image, a positive image and a negative image together with anchor_label
        # anchor image is the image according to idx
        # positive image is the image that has the same identity with the anchor image
        # negative image is the image that has the different identity with the anchor image
        anchor_img = self.images[idx]
        anchor_label = self.labels[idx]

        pos_idx = random.choice(self.label2indices[anchor_label])
        while pos_idx == idx:
            pos_idx = random.choice(self.label2indices[anchor_label])
        pos_img = self.images[pos_idx]
        pos_label = anchor_label
        neg_label = random.choice(list(set(self.labels) - {anchor_label}))
        neg_img = self.images[random.choice(self.label2indices[neg_label])]

        # utilize `self.transform' to convert images to tensors
        if self.transform is not None:
            anchor_img = self.transform(anchor_img)
            pos_img = self.transform(pos_img)
            neg_img = self.transform(neg_img)

        return anchor_img, pos_img, neg_img, anchor_label, pos_label, neg_label

# %%
image_size = 224
train_transform = transforms.Compose(
    [
        transforms.Resize((256, 256)),
        transforms.CenterCrop(image_size),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.ToTensor(),
        transforms.Normalize(
            mean=[0.5319, 0.4399, 0.3929], std=[0.3076, 0.2898, 0.2907]
        ),
    ]
)

val_transform = transforms.Compose(
    [
        transforms.Resize((256, 256)),
        transforms.CenterCrop(image_size),
        transforms.ToTensor(),
        transforms.Normalize(
            mean=[0.5319, 0.4399, 0.3929], std=[0.3076, 0.2898, 0.2907]
        ),
    ]
)

train_batch_size = 16
val_batch_size = 16
test_batch_size = 16

# declare the datasets and the dataloaders

train_triplet_dataset = TripletDataset(
    root_dir="large_prepared_data/train", transform=train_transform
)
train_triplet_dataloader = DataLoader(
    train_triplet_dataset, batch_size=train_batch_size, shuffle=True, num_workers=2
)

val_triplet_dataset = TripletDataset(
    root_dir="large_prepared_data/val", transform=val_transform
)
val_triplet_dataloader = DataLoader(
    val_triplet_dataset, batch_size=val_batch_size, shuffle=False, num_workers=2
)

test_triplet_dataset = TripletDataset(
    root_dir="large_prepared_data/test", transform=val_transform
)
test_triplet_dataloader = DataLoader(
    test_triplet_dataset, batch_size=test_batch_size, shuffle=False, num_workers=2
)

# %% [markdown]
# ## 2.2 Triplet Network
#
# This network is a simpliflied version of strong baseline person re-identification task (ref: https://arxiv.org/abs/1903.07071)
#
# Triplet network consists of 3 modules
#
# 1. Feature extractor (ResNet18) is for mapping an image to a feature map
# 2. Global pooling (Global average pooling or use flatten instead) is for converting a feature map to a feature vector
# 3. Bottleneck (Batch normalization only scale not shift) is for the consistency of training between triplet loss and crossentropy because it is difficult to optimize those losses in embedding space at the same time
# 4. Linear classifier is to classify who this face is
#
# **Note**
#
# 1. ResNet18 can call via `torchvision` library (How to use torchvision: https://pytorch.org/vision/stable/models.html)
# 2. ResNet18 we use will not load pretrained weights
# 3. We will use ResNet18 only extracting feature maps.
#
# **Hint!**
#
# 1. For global average pooling, read the documentation of `nn.AdaptiveAvgPool2d`
# 2. For bottleneck, try `requires_grad_` method to stop calculating gradient at batch normalization
#
# Figure 3 Triplet network
#
# ![Screen Shot 2565-04-01 at 12.23.31.png](data:image/png;base64,...)

# %%
def weights_init_kaiming(m):
    classname = m.__class__.__name__
    if m.affine:
        nn.init.constant_(m.weight, 1.0)
        nn.init.constant_(m.bias, 0.0)


def weights_init_classifier(m):
    classname = m.__class__.__name__
    if classname.find("Linear") != -1:
        nn.init.normal_(m.weight, std=0.001)
        if m.bias:
            nn.init.constant_(m.bias, 0.0)


class TripletNetwork(nn.Module):
    # implement the triplet network
    def __init__(self, num_classes):
        super(TripletNetwork, self).__init__()
        resnet = torchvision.models.resnet18(pretrained=False)
        self.conv = torch.nn.Sequential(*(list(resnet.children())[:-1]))
        self.global_pool = nn.AdaptiveAvgPool2d(1)

        self.bottleneck = nn.BatchNorm1d(512)
        # no shift
        self.bottleneck.bias.requires_grad_(False)

        self.classifier = nn.Linear(512, num_classes, bias=False)

        self.bottleneck.apply(weights_init_kaiming)
        self.classifier.apply(weights_init_classifier)

    def extract_feature(self, x):
        x = self.conv(x)

        global_feat = self.global_pool(x)
        global_feat = global_feat.view(global_feat.size(0), -1)

        feat = self.bottleneck(global_feat)

        if not self.training:
            return feat

        cls_score = self.classifier(feat)

        return global_feat, cls_score

    def forward(self, anchor_img, pos_img, neg_img):
        anchor_feat, anchor_score = self.extract_feature(anchor_img)
        pos_feat, pos_score = self.extract_feature(pos_img)
        neg_feat, neg_score = self.extract_feature(neg_img)

        feats = torch.cat((anchor_feat, pos_feat, neg_feat))
        scores = torch.cat((anchor_score, pos_score, neg_score))
        return anchor_feat, pos_feat, neg_feat, feats, scores

# %% [markdown]
# ## 2.3 Triplet loss
#
# Triplet loss uses the same concept as contrastive loss that is the anchor image will pull the positive one closer and push the negative one further than the constant margin away. Hence, we have sampled three images to compute it.
# The three images consist of:
#
# 1. an anchor image = an initial image
# 2. a positive image = the image having the same identity as the anchor image
# 3. a negative image = the image having a different identity from the anchor image
#
# The triplet loss is mathematically defined as:
#
# $L_{Triplet} = max(0, m + d(r_a, r_p) - d(r_a, r_n))$
#
# where
#
# - $d(r_1, r_2)$ = euclidean distance between $r_1$ and $r_2$
# - $m$ = margin
# - $r_a$ = the feature vector of the anchor image
# - $r_p$ = the feature vector of the positive image
# - $r_n$ = the feature vector of the negative image
#
# The loss aims to minimize $d(r_a, r_p)$ while maximizing $d(r_a, r_n)$ at the same time.
#
# The margin $m$ is used to prevent the loss from collapsing to a trivial solution. For instance, when $m = 0$, the model could achieve $L = 0$ just by exploiting the objective by setting $r_a = r_p = r_n$, and the model, as a result, would learn nothing useful.

# %%
class TripletLoss(nn.Module):
    # implement the triplet loss
    def __init__(self, margin=2.0):
        super(TripletLoss, self).__init__()
        self.margin = margin
        self.euclidean_dist_fn = nn.PairwiseDistance(p=2)

    def forward(self, anchor_img, pos_img, neg_img):
        pos_dist = self.euclidean_dist_fn(anchor_img, pos_img)
        neg_dist = self.euclidean_dist_fn(anchor_img, neg_img)
        return torch.mean(torch.relu(pos_dist - neg_dist + self.margin))

# %% [markdown]
# ## 2.4 Center loss
#
# Reference: https://ydwen.github.io/papers/WenECCV16.pdf
#
# **Definition**
#
# Centroid: a representative of each class. There are several ways to select a representative, one way to do this is to take an average on those embeddings.
#
# **Concept**
#
# Center loss enforces the intra-class feature vectors to come closer to the centroid of their class so that all feature vectors of the same identity are clustered around a single centroid. Since the model is updated after each iteration, the centroids should also be updated accordingly. However, re-calculating the centroids by averaging the feature vectors for each class every iteration is computational-extensive on a large scale. Therefore, the centroid is instead learned from the representative of each class from the sampled data.
#
# **Implementation detail**
#
# In `__init__` method
#
# 1. For simplicity, we will store the centroids in the class `CenterLoss`. Therefore, you have to initialize the centroids as a random tensor with the size of `(num_classes, feature_dimension)`. The tensor has to be set with `nn.Paramater` so that the gradient could be calculated (ref: https://pytorch.org/docs/stable/generated/torch.nn.parameter.Parameter.html).
#
# In the `forward` method
#
# 1. Calculate the distance between the feature vector and its center with a squared Euclidean distance
# 2. Clip the value in each element to be not greater than 1e+12, not lower than 1e-12, and sum them
# 3. Normalize the loss with its batch size
#
# **Center loss equation**
#
# $L_{Center} = \frac{1}{B}\sum_{j=1}^{B}||f_{j} - c_{y_j}||_2^2$
#
# where
#
# - $f_{j}$ = a feature vector before fed into the bottleneck at index $j$
# - $c_{y_j}$ = a center of the class corresponded to the index $j$
# - B = batch size
#
# The center loss minimized the distance between the feature vector and the centroid of the corresponded identity.
#
# **Note**
#
# 1. At `__init__` method in step 1. Do not forget to transfer the parameters to GPU with `.cuda()` otherwise, it will not utilize GPU on this part.
# 2. Clip the magnitude of the loss at the final stage before updating both upper bound and lower bound to avoid vanishing / exploding gradients.
#
# **Hint**
#
# 1. In step 2 of the `forward` method, you should use `torch.clamp` (ref: https://pytorch.org/docs/stable/generated/torch.clamp.html) to clip the lower bound and the upper bound as you want.

# %%
class CenterLoss(nn.Module):
    def __init__(self, num_classes, feat_dim):
        super(CenterLoss, self).__init__()
        self.device = "cuda" if torch.cuda.is_available() else "cpu"
        self.num_classes = num_classes
        self.feat_dim = feat_dim
        self.centers = nn.Parameter(
            torch.randn(self.num_classes, self.feat_dim).to(self.device)
        )

    def forward(self, x, labels):
        batch_size = x.size(0)
        # compute squared euclidean distance
        distmat = (
            torch.pow(x, 2)
            .sum(dim=1, keepdim=True)
            .expand(batch_size, self.num_classes)
            + torch.pow(self.centers, 2)
            .sum(dim=1, keepdim=True)
            .expand(self.num_classes, batch_size)
            .t()
        )
        distmat.addmm_(1, -2, x, self.centers.t())

        classes = torch.arange(self.num_classes).long().to(self.device)
        labels = labels.unsqueeze(1).expand(batch_size, self.num_classes)
        mask = labels.eq(classes.expand(batch_size, self.num_classes))

        dist = distmat * mask.float()
        loss = dist.clamp(min=1e-12, max=1e12).sum() / batch_size
        return loss

# %%
center_loss_fn = CenterLoss(80, 512)
feats = torch.randn(32, 512).cuda()
labels = torch.randn(32).cuda()
center_loss_fn(feats, labels)

# %% [markdown]
# ## 2.5 Declare model, criterions, optimizers, hyparameters and scheduler

# %%
# for triplet loss
triplet_margin = 3.0

# get the number of classes to construct a linear classifier and the parameters in center loss
num_classes = len(set(train_triplet_dataset.labels))
print(f"num_classes = {num_classes}")

# declare the triplet model and the triplet criterion
triplet_model = TripletNetwork(num_classes)
triplet_criterion = TripletLoss(margin=triplet_margin)

triplet_optimizer = optim.Adam(triplet_model.parameters(), lr=5e-4)
triplet_scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    triplet_optimizer, "min", patience=4, factor=0.1, min_lr=1e-8
)

# declare cross entropy loss
crossentropy_criterion = nn.CrossEntropyLoss()

# For center loss
# declare the center criterion
triplet_center_criterion = CenterLoss(num_classes, 512)

triplet_center_optimizer = optim.Adam(triplet_center_criterion.parameters(), lr=0.5)
triplet_center_loss_weight = 5e-2

# %% [markdown]
# ## 2.6 Training loop

# %% [markdown]
# The figure below shows how the center loss is updated in the original paper. $L_s$ $L_c$, $W$, $\theta_c$ and $c_j$ stand for classification loss, center loss, classification head's weight, CNN weight, and centroid of the class $j$, respectively. Line 6 shows how centroids are updated.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Joint loss equation**
#
# $L_{Joint} = L_{ID} + L_{Triplet} + \beta L_{Center}$
#
# where
#
# - $L_{Joint}$ = joint loss
# - $L_{ID}$ = identity loss (cross entropy loss in this implementation)
# - $L_{Triplet}$ = triplet loss
# - $L_{Center}$ = center loss
# - $\beta$ = center loss weights (affects only the triplet network, not center update)

# %% [markdown]
# The training procedure of the triplet network consists of the following steps:
#
# 1. Forward pass the `anchor_img`
# 2. Forward pass the `positive_img`
# 3. Forward pass the `negative_img`
# 4. Calculate the distance between the feature vectors of `anchor_img`, `positive_img` and `negative_img` and calculate a triplet loss ($L_{Triplet}$).
# 5. Calculate the classification loss ($L_{ID}$).
# 6. Calculate the center loss ($L_{Center}$).
# 7. Scale the center loss with the predetermined weight ($\beta$) (only used to update the triplet network not to update the centroids).
# 8. Sum the losses from steps 4-7 and update the triplet network. (Line 3-5)
# 9. Rescale the gradients with $\frac{1}{\beta}$ at the loss in step 7 and update the centroids. (Line 6-7)
# 10. Repeat steps 1-9 till converge
#
# As you would notice, steps 1- 3 share the same model weight for feature extraction. Thus, the word "triplet" in triplet loss originates in a similar fashion as the "Siamese twins" but this loss function utilizes three feature vectors simultaneously instead of two.
#
# **Hint**
#
# 1. At the gradient rescaling for the centroids, we should iterate parameters in center loss first with `.parameters()` and adjust the property of each parameter with `.grad.data`

# %%
num_epochs = 20
device = "cuda" if torch.cuda.is_available() else "cpu"

os.makedirs("weights", exist_ok=True)
best_weights_path = "weights/best_triplet_weights.pth"
triplet_model.to(device)
min_val_loss = float("inf")

train_losses = []
train_triplet_losses = []
train_crossentropy_losses = []
train_center_losses = []

val_losses = []
val_triplet_losses = []

for epoch in tqdm(range(num_epochs)):
    triplet_model.train()
    total_train_loss = 0
    total_train_triplet_loss = 0
    total_train_crossentropy_loss = 0
    total_train_center_loss = 0
    for anchor_img, pos_img, neg_img, anchor_label, pos_label, neg_label in tqdm(
        train_triplet_dataloader
    ):

        # feed data to the triplet model and compute triplet loss
        anchor_img, pos_img, neg_img = (
            anchor_img.to(device),
            pos_img.to(device),
            neg_img.to(device),
        )
        anchor_label, pos_label, neg_label = (
            anchor_label.to(device),
            pos_label.to(device),
            neg_label.to(device),
        )
        labels = torch.cat((anchor_label, pos_label, neg_label))

        anchor_feat, pos_feat, neg_feat, feats, scores = triplet_model(
            anchor_img, pos_img, neg_img
        )
        train_triplet_loss = triplet_criterion(anchor_feat, pos_feat, neg_feat)

        # compute cross entropy loss
        train_crossentropy_loss = crossentropy_criterion(scores, labels)

        # compute center loss
        train_center_loss = triplet_center_loss_weight * triplet_center_criterion(
            feats, labels
        )

        train_loss = train_triplet_loss + train_crossentropy_loss + train_center_loss
        total_train_loss += train_loss.item()
        total_train_triplet_loss += train_triplet_loss.item()
        total_train_crossentropy_loss += train_crossentropy_loss.item()
        total_train_center_loss += train_center_loss.item()

        # set zero gradients at two optimizers
        triplet_optimizer.zero_grad()
        triplet_center_optimizer.zero_grad()

        # back propagate at triplet network and step the main optimizer
        train_loss.backward()
        triplet_optimizer.step()

        # rescale gradients of centers because `triplet_center_loss_weight` should not affect to learning the centers
        # and step the center optimizer
        for param in triplet_center_criterion.parameters():
            param.grad.data *= 1.0 / triplet_center_loss_weight
        triplet_center_optimizer.step()

    current_train_loss = total_train_loss / len(train_triplet_dataloader)
    current_train_triplet_loss = total_train_triplet_loss / len(
        train_triplet_dataloader
    )
    current_train_crossentropy_loss = total_train_crossentropy_loss / len(
        train_triplet_dataloader
    )
    current_train_center_loss = total_train_center_loss / len(train_triplet_dataloader)
    train_losses.append(current_train_loss)
    train_triplet_losses.append(current_train_triplet_loss)
    train_crossentropy_losses.append(current_train_crossentropy_loss)
    train_center_losses.append(current_train_center_loss)

    total_val_loss = 0
    total_val_triplet_loss = 0
    triplet_model.eval()
    for val_anchor_img, val_pos_img, val_neg_img, _, _, _ in val_triplet_dataloader:

        # feed data to the triplet model and compute triplet loss
        val_anchor_img, val_pos_img, val_neg_img = (
            val_anchor_img.to(device),
            val_pos_img.to(device),
            val_neg_img.to(device),
        )
        with torch.no_grad():
            val_anchor_feat = triplet_model.extract_feature(val_anchor_img)
            val_pos_feat = triplet_model.extract_feature(val_pos_img)
            val_neg_feat = triplet_model.extract_feature(val_neg_img)
            val_triplet_loss = triplet_criterion(
                val_anchor_feat, val_pos_feat, val_neg_feat
            )

        val_loss = val_triplet_loss
        total_val_loss += val_loss.item()
        total_val_triplet_loss += val_triplet_loss.item()
    current_val_loss = total_val_loss / len(val_triplet_dataloader)
    current_val_triplet_loss = total_val_triplet_loss / len(val_triplet_dataloader)
    val_losses.append(current_val_loss)
    val_triplet_losses.append(current_val_triplet_loss)

    if current_val_loss < min_val_loss:
        min_val_loss = current_val_loss
        torch.save(triplet_model.state_dict(), best_weights_path)
    print(
        f'Epoch {epoch+1} - Train loss = {current_train_loss:.4f} - Train triplet loss = {current_train_triplet_loss:.4f} - Train crossentropy loss = {current_train_crossentropy_loss:.4f}  - Train center loss = {current_train_center_loss:.4f} - Val loss = {current_val_loss:.4f} - Val triplet loss = {current_val_triplet_loss:.4f} - best min_val_loss = {min_val_loss:.4f} - lr = {triplet_optimizer.param_groups[0]["lr"]:.8f}'
    )
    triplet_scheduler.step(current_val_loss)

# %% [markdown]
# ## 2.7 Visualization
#
# The visualization below displays an anchor, positive, and negative image and their respective distance.

# %%
# Showing images
def imshow(img, text=None):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(
            20,
            8,
            text,
            style="italic",
            fontweight="bold",
            bbox={"facecolor": "white", "alpha": 0.8, "pad": 10},
        )

    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


best_weights_path = "weights/best_triplet_weights.pth"
triplet_model.to(device)
triplet_model.load_state_dict(torch.load(best_weights_path))
triplet_model.eval()

test_anchor_imgs, test_pos_imgs, test_neg_imgs, test_anchor_ids, _, _ = next(
    iter(test_triplet_dataloader)
)
test_anchor_imgs, test_pos_imgs, test_neg_imgs = (
    test_anchor_imgs.to(device),
    test_pos_imgs.to(device),
    test_neg_imgs.to(device),
)
with torch.no_grad():
    test_anchor_feats = triplet_model.extract_feature(test_anchor_imgs)
    test_pos_feats = triplet_model.extract_feature(test_pos_imgs)
    test_neg_feats = triplet_model.extract_feature(test_neg_imgs)


class UnNormalize(object):
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std

    def __call__(self, tensor):
        """
        Args:
            tensor (Tensor): Tensor image of size (C, H, W) to be normalized.
        Returns:
            Tensor: Normalized image.
        """
        for t, m, s in zip(tensor, self.mean, self.std):
            t.mul_(s).add_(m)
            # The normalize code -> t.sub_(m).div_(s)
        return tensor


unnormalizer = UnNormalize(mean=[0.5319, 0.4399, 0.3929], std=[0.3076, 0.2898, 0.2907])

zip_test_data = zip(
    test_anchor_feats,
    test_pos_feats,
    test_neg_feats,
    test_anchor_imgs,
    test_pos_imgs,
    test_neg_imgs,
)
for (
    test_anchor_feat,
    test_pos_feat,
    test_neg_feat,
    test_anchor_img,
    test_pos_img,
    test_neg_img,
) in zip_test_data:
    test_anchor_img = unnormalizer(test_anchor_img.detach().cpu().unsqueeze(0))
    test_pos_img = unnormalizer(test_pos_img.detach().cpu().unsqueeze(0))
    test_neg_img = unnormalizer(test_neg_img.detach().cpu().unsqueeze(0))
    concatenated = torch.cat((test_anchor_img, test_pos_img, test_neg_img), 0)
    anc_pos_distance = F.pairwise_distance(
        test_anchor_feat.unsqueeze(0), test_pos_feat.unsqueeze(0)
    )
    anc_neg_distance = F.pairwise_distance(
        test_anchor_feat.unsqueeze(0), test_neg_feat.unsqueeze(0)
    )
    imshow(
        torchvision.utils.make_grid(concatenated),
        f"Anc-Pos Distance: {anc_pos_distance.item():.4f}, Anc-Neg Distance: {anc_neg_distance.item():.4f}",
    )

# %% [markdown]
# ## 2.8 Plot loss history

# %%
import matplotlib.pyplot as plt

plt.plot(np.arange(1, len(train_losses) + 1), train_losses, label="train loss")
plt.plot(np.arange(1, len(val_losses) + 1), val_losses, label="val loss")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(
    np.arange(1, len(train_losses) + 1),
    train_triplet_losses,
    label="train triplet loss",
)
plt.plot(
    np.arange(1, len(val_losses) + 1), val_triplet_losses, label="val triplet loss"
)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(
    np.arange(1, len(train_losses) + 1), train_center_losses, label="train center loss"
)
plt.legend()
plt.show()

# %% [markdown]
# ## 2.9 (TODO) Plot t-SNE
#
# This section is similar to section 1.8 but the network is instead optimized using a combined triplet, center, and cross-entropy loss.
#
# **Instructions**
#
# TODO 12: Extract the feature vectors of the test set and store them as
#
# `embeddings`: torch.FloatTensor = feature vectors of all images in the test set
#
# `identities`: list or torch.Tensor or np.array = identities of all images in the test set
#
# **Hint**
# Use `FaceDataset` that is imported at `Common Dataset` section
#
# **WARNING!!**
# Don't forget load its best weights and change to eval mode first

# %%
test_batch_size = 32

# TODO 12: Extract the feature vectors of the test set and store them as
# `embeddings`: torch.FloatTensor = feature vectors of all images in the test set
# `identities`: list or torch.Tensor or np.array = identities of all images in the test set
# Hint      => Use `FaceDataset` that is imported at `Common Dataset` section
# WARNING!! => Don't forget load its best weights and change to eval mode first
embeddings = None
identities = None

# %%
import time
from sklearn.manifold import TSNE

time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=30, n_iter=3000)
tsne_result = tsne.fit_transform(embeddings)
print("t-SNE done! Time elapsed: {} seconds".format(time.time() - time_start))

# %%
import plotly.express as px

label = []
idx = 0
id2label = dict()
for identity in identities:
    identity = int(identity)
    if identity not in id2label:
        id2label[identity] = idx
        idx += 1
    label.append(id2label[identity])

df_subset = pd.DataFrame({"label": label})

df_subset["tsne-2d-one"] = tsne_result[:, 0]
df_subset["tsne-2d-two"] = tsne_result[:, 1]

fig = px.scatter(
    df_subset, x="tsne-2d-one", y="tsne-2d-two", color="label", height=1000, width=1000
)
fig.update_layout(margin=dict(l=0, r=0, b=0, t=0))
fig.show()

# %%
import time
from sklearn.manifold import TSNE

time_start = time.time()
tsne = TSNE(n_components=3, verbose=1, perplexity=30, n_iter=3000)
tsne_result = tsne.fit_transform(embeddings)
print("t-SNE done! Time elapsed: {} seconds".format(time.time() - time_start))

# %%
import plotly.express as px

label = []
idx = 0
id2label = dict()
for identity in identities:
    identity = int(identity)
    if identity not in id2label:
        id2label[identity] = idx
        idx += 1
    label.append(id2label[identity])

df_subset = pd.DataFrame({"label": label})

df_subset["tsne-3d-one"] = tsne_result[:, 0]
df_subset["tsne-3d-two"] = tsne_result[:, 1]
df_subset["tsne-3d-three"] = tsne_result[:, 2]

fig = px.scatter_3d(
    df_subset, x="tsne-3d-one", y="tsne-3d-two", z="tsne-3d-three", color="label"
)
fig.update_layout(margin=dict(l=0, r=0, b=0, t=0))
fig.show()

# %% [markdown]
# ## 2.10 (TODO) Embedding comparison

# %% [markdown]
# TODO 13: Compare the visualization of the triplet network to the siamese network. Which one is better and why?
#
# Answer here:

# %% [markdown]
# ## (Optional) Try other tricks to get higher quality of face embeddings such as
#
# 1. GeM Pooling (ref: https://amaarora.github.io/2020/08/30/gempool.html)
# 2. Arcface (ref: https://arxiv.org/abs/1801.07698)
# 3. Hard negative mining (ref: https://omoindrot.github.io/triplet-loss)
# 4. Semi-hard mining
#
# and plot t-SNE to compare with vanilla triplet loss

# %% [markdown]
# # Part 3 : Face recognition using InfoNCE loss

# %% [markdown]
# In contrast to the contrastive and triplet loss that only pulls an image pair of the same identity to come closer and push a different one away, some alternative approaches, such as the N-pair (ref: [paper](https://papers.nips.cc/paper_files/paper/2016/file/6b180037abbebea991d8b1232f8a8ca9-Paper.pdf)) and InfoNCE (ref: [paper](https://arxiv.org/pdf/1807.03748v2.pdf)) loss, take multiple positive images or/and multiple negative images into consideration. In this part, you are going to implement a variant of the InfoNCE loss where multiple positive and negative images are simutaneously utilized during the learning process. Moreover, the loss function implemented in this homework also adopts temperature scaling, a concept widely applied in many state-of-the-art self-supervised learning such as SimCLR (ref: [paper](https://arxiv.org/abs/2002.05709)), instead of the margin used in triplet and vanilla contrastive loss.

# %% [markdown]
# ## 3.1 (TODO) Dataset and DataLoader

# %% [markdown]
# In this section, you are going to implement a dataloader for the combined loss.
# The dataloader should return the tuple `(anchor_img, pos_imgs, neg_imgs, anchor_label, pos_labels, neg_labels)`.
#
# - The positive image must have the same identity as the anchor image.
# - The negative image must have a different identity from the anchor image.
#
# this dataloader will sample both multiple positive images and multiple negative images per anchor image

# %%
import copy


class InfoNCEDataset(Dataset):
    def __init__(self, root_dir, transform=None, num_pos=4, num_neg=8):
        np.random.seed(123)
        random.seed(123)
        self.root_dir = root_dir
        self.transform = transform
        self.num_pos = num_pos
        self.num_neg = num_neg

        label_df = pd.read_csv(f"{root_dir}/label_df.csv")
        label_df = (
            label_df.groupby("identity")["filename"]
            .apply(list)
            .reset_index()
            .rename({"filename": "filenames"}, axis=1)
        )
        self.images = []
        self.labels = []
        self.label2indices = dict()
        self.load_images_to_memory_(label_df)

    def load_images_to_memory_(self, label_df):
        # load images and labels into memory
        # We have to relabel from identities to 0,1,2,...,num_classes-1
        # Relevant variables
        # 1. `self.images` = PIL images  (Also convert it to RGB)
        # 2. `self.label2indices` = the dictionary storing a label as a key and the indices of images as value
        # 3. `self.labels` = labels of images (relabeled)
        # Note: the index of images is from iterating over label_df
        self.images = []
        self.label2indices = defaultdict(list)
        self.labels = []
        img_idx = 0
        label_idx = 0
        identity2label = dict()
        for idx in tqdm(range(len(label_df))):
            row = label_df.iloc[idx]
            identity, filenames = row["identity"], row["filenames"]

            if identity not in identity2label:
                identity2label[identity] = label_idx
                label_idx += 1

            label = identity2label[identity]

            for filename in filenames:
                self.images.append(
                    Image.open(f"{self.root_dir}/{filename}").convert("RGB")
                )
                self.labels.append(label)
                self.label2indices[label].append(img_idx)
                img_idx += 1

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        """
        sample images labels
        [args]
        - idx is an index of an image

        [intermediate]
        - anchor image is the image according to idx
        - positive images (dim: [num_pos, num_feat]) is a list of image that has the same identity with the anchor image (no duplicated images in this list)
        - negative images (dim: [num_neg, num_feat]) is a list of image that has the different identity with the anchor image (no duplicated images in this list)

        [return]
        - transformed_anchor_img is the transformed anchor image
        - transformed_pos_imgs are the tensor of transformed positive images
        - transformed_neg_img are the tensor of transformed negative images
        - anchor_label is the label of the anchor image
        - pos_labels are the list of positive labels
        - neg_labels are the list of negative labels
        """

        anchor_img = self.images[idx]
        anchor_label = self.labels[idx]

        # TODO 14: sample positive images corresponding with the identity of anchor image
        ## condition:
        ## - there is no duplicated positive images
        ### Hint: Please use self.num_pos to determine the number of sampled positive images
        pass

        # TODO 15: sample negative images that their identities differs from the identity of anchor image
        ## condition:
        ## - the list of negative images can contain identical identities
        ## - there is no duplicated negative images
        ### Hint: Please use self.num_neg to determine the number of sampled negative images
        pass

        # TODO 16: utilize `self.transform' to convert anchor image, positive images, and negative images to tensors
        # WARNING!: Don't forget to convert to be tensors
        pass

        return anchor_img, pos_imgs, neg_imgs, anchor_label, pos_labels, neg_labels

# %%
image_size = 224
train_transform = transforms.Compose(
    [
        transforms.Resize((256, 256)),
        transforms.CenterCrop(image_size),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.ToTensor(),
        transforms.Normalize(
            mean=[0.5319, 0.4399, 0.3929], std=[0.3076, 0.2898, 0.2907]
        ),
    ]
)

val_transform = transforms.Compose(
    [
        transforms.Resize((256, 256)),
        transforms.CenterCrop(image_size),
        transforms.ToTensor(),
        transforms.Normalize(
            mean=[0.5319, 0.4399, 0.3929], std=[0.3076, 0.2898, 0.2907]
        ),
    ]
)

train_batch_size = 16
val_batch_size = 16
test_batch_size = 16

# TODO 17: declare the datasets and the dataloaders
train_infonce_dataset = None
train_infonce_dataloader = None

val_infonce_dataset = None
val_infonce_dataloader = None

test_infonce_dataset = None
test_infonce_dataloader = None

# %% [markdown]
# ## 3.2 (TODO) Image encoder
#
# Image encoder consists of 3 modules
#
# 1. Feature extractor (ResNet18) is for mapping an image to a feature map
# 2. Global pooling (Global average pooling or use flatten instead) is for converting a feature map to a feature vector
# 3. Projection layer consists of 2 MLP layers to reduce dimension of feature vector together with a relu activation function at the middle of MLP layers
#
# **Note**
#
# 1. ResNet18 can call via `torchvision` library (How to use torchvision: https://pytorch.org/vision/stable/models.html)
# 2. ResNet18 we use will not load pretrained weights
# 3. We will use ResNet18 only extracting feature maps.
#
# **Hint!**
#
# 1. For global average pooling, read the documentation of `nn.AdaptiveAvgPool2d`
#
# Figure 8 Image Encoder
#
# ![Screenshot from 2024-03-21 05-05-33.png](data:image/png;base64,...)

# %%
class ImageEncoder(nn.Module):
    # TODO 18: implement the image encoder according to the above figure
    def __init__(self):
        super(ImageEncoder, self).__init__()
        pass

    def extract_feature(self, x):
        pass
        return output

    def forward(self, input1, input2, input3):
        pass
        return output1, output2, output3

# %% [markdown]
# ## 3.3 (TODO) InfoNCE loss
#
# Information Noise Contrastive Estimation (InfoNCE) loss (ref: [blog](https://lilianweng.github.io/posts/2021-05-31-contrastive/), [paper](https://arxiv.org/pdf/1807.03748v2.pdf)) is a self-supervised training objective aiming to maximizes the agreement between positive samples and minimizes the agreement between negative samples in the learned representation space. Although primarily designed for self-supervised learning, it could also be used in supervised setting by utilizing information from the labeled data.
#
# When under self-supervision, images are sampled in batches, each of which is then augmented using two different augmentation policies. The contrastive loss is subsequently computed to maximize the similarity of the images of the same origin before augmentation while minimizing the similarity of the ones with different origins. In supervised learning, the objective maximizes the similarity of the images with the same identity (class) instead of origin. <b>In this part, we will train the InfoNCE loss under the supervised setting.</b>
#
# To put it simply, the InfoNCE loss revolves around three types of images:
#
# 1. Anchor image: an initial image
# 2. Positive images: the sampled images with the same identity as the anchor image
# 3. Negative images: the sampled images whose identity differs from that of the anchor image
#
# The objective is to maximize the cosine similarity between groups 1 and 2 while pushing groups 1 and 3 away. Thus, the InfoNCE maximizes the following objective:
#
# \begin{align}
# InfoNCE\ Loss*i = \frac{1}{B \cdot P} \sum*{i=1}^B \sum*{p \in {P(i)}}-log \left( \frac{e^{(cos(f_i, f_p) / \tau)}}{(e^{cos(f_i, f_p) / \tau)} + \sum*{n \in N(i)} e^{(cos(f_i, f_n) / \tau)}} \right)
# \end{align}
#
# Notation
#
# - $B$ = batch size
# - $P$ = the number of positive images per anchor
# - $i$ = index of the anchor feature vector
# - $P(i)$ = the sampled positive feature vectors
# - $N(i)$ = the sampled negative feature vectors
# - $cos(f_i, f_p)$ = cosine similarity between $f_i$ and $f_p$
# - $f_i$ = anchor feature vector
# - $f_p$ = positive feature vector
# - $f_n$ = negative feature vector
# - $\tau$ = temperature (a scaling factor for increasing/reducing the magnitude of logits)
#
# **Hint** use `nn.CrossEntropy` to compute the exponential part

# %%
class InfoNCELoss(nn.Module):
    # TODO 19: implement the InfoNCE loss
    def __init__(self, device, temperature):
        super(InfoNCELoss, self).__init__()
        pass

    def forward(self, anchor_feat, pos_feats, neg_feats):
        pass

# %% [markdown]
# ## 3.4 (TODO) Initializing model, criterions, optimizers, hyparameters and scheduler

# %%
temperature = 0.2

infonce_model = ImageEncoder()
device = "cuda" if torch.cuda.is_available() else "cpu"
train_infonce_criterion = InfoNCELoss(device, temperature)
val_infonce_criterion = InfoNCELoss(device, temperature)

infonce_optimizer = optim.Adam(infonce_model.parameters(), lr=5e-4)
infonce_scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    infonce_optimizer, "min", patience=4, factor=0.1, min_lr=1e-8
)

# %% [markdown]
# ## 3.5 (TODO) Training loop
#
# Figure 9 How to connect the InfoNCE loss
#
# ![Screen Shot 2565-04-01 at 14.43.49-2.png](data:image/png;base64,...)

# %% [markdown]
# Fig 9 demonstrates how to connect multiple feature vectors to compute InfoNCE loss. The feature extractor shares all parameters between input images.

# %% [markdown]
# The training procedure of a infonce network consists of the following steps:
#
# 1. Foward pass `anchor_img`
# 2. Foward pass `pos_imgs`
# 3. Foward pass `neg_img`
# 4. Calculate all pairs cosine similarities between `anchor_img` and `pos_imgs`.
# 5. Calculate all pairs cosine similarities between `anchor_img` and `neg_imgs`.
# 6. Compute InfoNCE loss and take an average over them
# 7. Use the loss in step 6 to update the model
# 8. Repeat step 1-8 till converged
#
# TODO 20: move training data to GPU memory, extract anchor, positive, negative features from images, and then use them to compute InfoNCE loss
#
# TODO 21: set zero gradients
#
# TODO 22 : back propagate at infonce network and step the optimizer
#
# TODO 23: move validation data to GPU memory, extract anchor, positive, negative features from images, and then use them to compute InfoNCE loss

# %%
num_epochs = 20
device = "cuda" if torch.cuda.is_available() else "cpu"

os.makedirs("weights", exist_ok=True)
best_weights_path = "weights/best_infonce_weights.pth"
infonce_model.to(device)
min_val_loss = float("inf")

train_losses = []
val_losses = []

for epoch in tqdm(range(num_epochs)):
    infonce_model.train()
    total_train_loss = 0
    for anchor_img, pos_imgs, neg_imgs, anchor_label, pos_labels, neg_labels in tqdm(
        train_infonce_dataloader
    ):

        # TODO 20: feed data to the infonce model and compute infonce loss
        pass
        total_train_loss += train_loss.item()

        # TODO 21: set zero gradients
        pass

        # TODO 22 : back propagate at infonce network and step the optimizer
        pass

    current_train_loss = total_train_loss / len(train_infonce_dataloader)
    train_losses.append(current_train_loss)

    total_val_loss = 0
    infonce_model.eval()

    for val_anchor_img, val_pos_imgs, val_neg_imgs, _, _, _ in val_infonce_dataloader:
        # TODO 23: feed data to the infonce model and compute infonce loss
        pass

        val_loss = val_infonce_loss
        total_val_loss += val_loss.item()
    current_val_loss = total_val_loss / len(val_infonce_dataloader)
    val_losses.append(current_val_loss)

    if current_val_loss < min_val_loss:
        min_val_loss = current_val_loss
        torch.save(infonce_model.state_dict(), best_weights_path)
    print(
        f"Epoch {epoch+1} "
        f"- Train loss = {current_train_loss:.4f} "
        f"- Val loss = {current_val_loss:.4f} "
        f"- best min_val_loss = {min_val_loss:.4f} "
        f'- lr = {infonce_optimizer.param_groups[0]["lr"]:.8f}'
    )
    infonce_scheduler.step(current_val_loss)

# %% [markdown]
# ## 3.6 Visualization
#
# The visualization below displays an anchor, positive, and negative image and their respective similarity.

# %%
# Showing images
def imshow(img, text=None):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(
            20,
            8,
            text,
            style="italic",
            fontweight="bold",
            bbox={"facecolor": "white", "alpha": 0.8, "pad": 10},
        )

    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


best_weights_path = "weights/best_infonce_weights.pth"
infonce_model.to(device)
infonce_model.load_state_dict(torch.load(best_weights_path))
infonce_model.eval()

test_anchor_imgs, batch_test_pos_imgs, batch_test_neg_imgs, test_anchor_ids, _, _ = (
    next(iter(test_infonce_dataloader))
)

test_pos_imgs = batch_test_pos_imgs[:, 0, :, :]
test_neg_imgs = batch_test_neg_imgs[:, 0, :, :]

test_anchor_imgs, test_pos_imgs, test_neg_imgs = (
    test_anchor_imgs.to(device),
    test_pos_imgs.to(device),
    test_neg_imgs.to(device),
)
with torch.no_grad():
    test_anchor_feats = infonce_model.extract_feature(test_anchor_imgs)
    test_pos_feats = infonce_model.extract_feature(test_pos_imgs)
    test_neg_feats = infonce_model.extract_feature(test_neg_imgs)


class UnNormalize(object):
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std

    def __call__(self, tensor):
        """
        Args:
            tensor (Tensor): Tensor image of size (C, H, W) to be normalized.
        Returns:
            Tensor: Normalized image.
        """
        for t, m, s in zip(tensor, self.mean, self.std):
            t.mul_(s).add_(m)
            # The normalize code -> t.sub_(m).div_(s)
        return tensor


unnormalizer = UnNormalize(mean=[0.5319, 0.4399, 0.3929], std=[0.3076, 0.2898, 0.2907])

zip_test_data = zip(
    test_anchor_feats,
    test_pos_feats,
    test_neg_feats,
    test_anchor_imgs,
    test_pos_imgs,
    test_neg_imgs,
)
for (
    test_anchor_feat,
    test_pos_feat,
    test_neg_feat,
    test_anchor_img,
    test_pos_img,
    test_neg_img,
) in zip_test_data:
    test_anchor_img = unnormalizer(test_anchor_img.detach().cpu().unsqueeze(0))
    test_pos_img = unnormalizer(test_pos_img.detach().cpu().unsqueeze(0))
    test_neg_img = unnormalizer(test_neg_img.detach().cpu().unsqueeze(0))
    concatenated = torch.cat((test_anchor_img, test_pos_img, test_neg_img), 0)
    anc_pos_similarity = F.cosine_similarity(
        test_anchor_feat.unsqueeze(0), test_pos_feat.unsqueeze(0)
    )
    anc_neg_similarity = F.cosine_similarity(
        test_anchor_feat.unsqueeze(0), test_neg_feat.unsqueeze(0)
    )
    imshow(
        torchvision.utils.make_grid(concatenated),
        f"Anc-Pos similarity: {anc_pos_similarity.item():.4f}, Anc-Neg similarity: {anc_neg_similarity.item():.4f}",
    )

# %% [markdown]
# ## 3.7 Plot loss history

# %%
import matplotlib.pyplot as plt

plt.plot(np.arange(1, len(train_losses) + 1), train_losses, label="train loss")
plt.plot(np.arange(1, len(val_losses) + 1), val_losses, label="val loss")
plt.legend()
plt.title("Loss")
plt.show()

# %% [markdown]
# ## 3.8 (TODO) Plot t-SNE
#
# This section is similar to section 1.8
#
# **Instructions**
#
# TODO 24: Extract the feature vectors of the test set and store them as
#
# `embeddings`: torch.FloatTensor = feature vectors of all images in the test set
#
# `identities`: list or torch.Tensor or np.array = identities of all images in the test set
#
# **Hint**
# Use `FaceDataset` that is imported at `Common Dataset` section
#
# **WARNING!!**
# Don't forget load its best weights and change to eval mode first

# %%
test_batch_size = 32

# TODO 24: Extract the feature vectors of the test set and store them as
# `embeddings`: torch.FloatTensor = feature vectors of all images in the test set
# `identities`: list or torch.Tensor or np.array = identities of all images in the test set
# Hint      => Use `FaceDataset` that is imported at `Common Dataset` section
# WARNING!! => Don't forget load its best weights and change to eval mode first
embeddings = None
identities = None

# %%
import time
from sklearn.manifold import TSNE

time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=30, n_iter=3000)
tsne_result = tsne.fit_transform(embeddings)
print("t-SNE done! Time elapsed: {} seconds".format(time.time() - time_start))

# %%
import plotly.express as px

label = []
idx = 0
id2label = dict()
for identity in identities:
    identity = int(identity)
    if identity not in id2label:
        id2label[identity] = idx
        idx += 1
    label.append(id2label[identity])

df_subset = pd.DataFrame({"label": label})

df_subset["tsne-2d-one"] = tsne_result[:, 0]
df_subset["tsne-2d-two"] = tsne_result[:, 1]

fig = px.scatter(
    df_subset, x="tsne-2d-one", y="tsne-2d-two", color="label", height=1000, width=1000
)
fig.update_layout(margin=dict(l=0, r=0, b=0, t=0))
fig.show()

# %%
import time
from sklearn.manifold import TSNE

time_start = time.time()
tsne = TSNE(n_components=3, verbose=1, perplexity=30, n_iter=3000)
tsne_result = tsne.fit_transform(embeddings)
print("t-SNE done! Time elapsed: {} seconds".format(time.time() - time_start))

# %%
import plotly.express as px

label = []
idx = 0
id2label = dict()
for identity in identities:
    identity = int(identity)
    if identity not in id2label:
        id2label[identity] = idx
        idx += 1
    label.append(id2label[identity])

df_subset = pd.DataFrame({"label": label})

df_subset["tsne-3d-one"] = tsne_result[:, 0]
df_subset["tsne-3d-two"] = tsne_result[:, 1]
df_subset["tsne-3d-three"] = tsne_result[:, 2]

fig = px.scatter_3d(
    df_subset, x="tsne-3d-one", y="tsne-3d-two", z="tsne-3d-three", color="label"
)
fig.update_layout(margin=dict(l=0, r=0, b=0, t=0))
fig.show()

# %% [markdown]
# ## 3.9 (TODO) Please analyze and compare between the t-SNE of triplet network the t-SNE of InfoNCE network. Why are those t-SNEs not in the same way?

# %% [markdown]
# TODO 25: Answer the above question
#
# **Hint** The reason is about our dataset
#
# Answer:

# %% [markdown]
# # Part 4 : Face verification evaluation
#
# In HW3, we use the ROC curve to measure the performance of the face verification task. Similarly, we will use this metric to measure the performance of our NN.
#
# TODO 26: Use the Siamese network, network trained using triplet loss, and network trained using InfoNCE loss to extract the image features from the test set.

# %%
val_transform = transforms.Compose(
    [
        transforms.Resize((256, 256)),
        transforms.CenterCrop(img_size),
        transforms.ToTensor(),
        transforms.Normalize(
            mean=[0.5319, 0.4399, 0.3929], std=[0.3076, 0.2898, 0.2907]
        ),
    ]
)


test_siamese_dataset = SiameseDataset(
    root_dir="large_prepared_data/test", transform=val_transform
)
test_siamese_dataloader = DataLoader(
    test_siamese_dataset, batch_size=test_batch_size, shuffle=False, num_workers=2
)

siamese_embeddings1 = []
siamese_embeddings2 = []
triplet_embeddings1 = []
triplet_embeddings2 = []
infonce_embeddings1 = []
infonce_embeddings2 = []
labels = []

device = "cuda" if torch.cuda.is_available() else "cpu"

siamese_model.to(device)
triplet_model.to(device)
infonce_model.to(device)

siamese_model.load_state_dict(torch.load("weights/best_siamese_weights.pth"))
triplet_model.load_state_dict(torch.load("weights/best_triplet_weights.pth"))
infonce_model.load_state_dict(torch.load("weights/best_infonce_weights.pth"))

siamese_model.eval()
triplet_model.eval()
infonce_model.eval()

for batch_img1, batch_img2, batch_label in tqdm(test_siamese_dataloader):
    batch_img1, batch_img2, batch_label = (
        batch_img1.to(device),
        batch_img2.to(device),
        batch_label.to(device),
    )
    with torch.no_grad():
        # TODO 26: extract features with both siamese network, triplet network, infonce network
        # and keep embeddings in provided lists according to variable names
        siamese_embeddings1.append(None)
        siamese_embeddings2.append(None)
        triplet_embeddings1.append(None)
        triplet_embeddings2.append(None)
        infonce_embeddings1.append(None)
        infonce_embeddings2.append(None)

    labels.append(batch_label)

siamese_embeddings1 = torch.cat(siamese_embeddings1)
siamese_embeddings2 = torch.cat(siamese_embeddings2)
triplet_embeddings1 = torch.cat(triplet_embeddings1)
triplet_embeddings2 = torch.cat(triplet_embeddings2)
infonce_embeddings1 = torch.cat(infonce_embeddings1)
infonce_embeddings2 = torch.cat(infonce_embeddings2)
labels = torch.cat(labels)

# %% [markdown]
# TODO 27: Measure the similarity score between the two feature vectors with cosine similarity.
#
# **HINT**
# You can use `nn.CosineSimilarity`
# (ref: https://pytorch.org/docs/stable/generated/torch.nn.CosineSimilarity.html).

# %%
def compute_pairs_cosine_sim(input1, input2):
    # TODO 27: implement cosine similarity function that can compute multiple pairs at the same time
    pass


siamese_scores = compute_pairs_cosine_sim(siamese_embeddings1, siamese_embeddings2)
triplet_scores = compute_pairs_cosine_sim(triplet_embeddings1, triplet_embeddings2)
infonce_scores = compute_pairs_cosine_sim(infonce_embeddings1, infonce_embeddings2)

# %% [markdown]
# TODO 28
#
# Plot a ROC curve to compare the performance siamese, triplet, infonce networks. Which one is better and why?

# %%
import matplotlib.pyplot as plt

# TODO 28: calculate true positive rate and false positive rate
# and plot both the ROC curve of siamese network and the ROC curve of triplet network
# together with AUC score
